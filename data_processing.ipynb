# %% [markdown]
# **Table of Contents**
#
# - [Step 1: Pre-Setting](#step-1-pre-setting)
# - [Step 2: Standardize All Initial Files into PDFs](#step-2-standardize-all-initial-files-into-pdfs)
# - [Step 3: Convert All PDFs to JSON (Unstructured)](#step-3-convert-all-pdfs-to-json-unstructured)
# - [Step 4: Analyze Feedback and Assign Labels to Original Data](#step-4-analyze-feedback-and-assign-labels-to-original-data)
#   - [4.1: Explore the raw feedback json.txt File](#41-explore-the-raw-feedback-jsontxt-file)
#   - [4.2: Merge Excel Columns into JSON & Inspect InitialDMPReviewStatus](#42-merge-excel-columns-into-json--inspect-initialdmpreviewstatus)
#   - [4.3: Filter and Generate Review JSON Files](#43-filter-and-generate-review-json-files)
#   - [4.4: Analysis of Status Discrepancies between Original JSON and Excel and generate the rest Review Json file](#44-analysis-of-status-discrepancies-between-original-json-and-excel-and-generate-the-rest-review-json-file)
# - [Step 5: Build Dataset Records and Split into Train/Dev/Test](#step-5-build-dataset-records-and-split-into-traindevtest)
# - [Step 6: Ready for Hugging Face dataset](#step-6-ready-for-hugging-face-dataset)

# %% [markdown]
# ### Step 1: Pre-Setting
#
# This step prepares the environment for processing DMP (Data Management Plan) files.
#
# **Tasks:**
#
# 1. **Configure paths**
#    - Set base directories:
#      - `DataManagementPlans/`: contains the original DMP folders
#      - `processed_data/`: output folders for processed files
#
# 2. **Create required subfolders**
#    - `processed_data/pdfs/`
#    - `processed_data/docs/`
#    - `processed_data/parsed_files/`
#    - `processed_data/splits/`
#
# 3. **Load metadata from `dmpmt.json`**
#    - This file contains metadata entries for each DMP
#    - Use the `LinkTitle` field (a unique ID) to **link metadata to its corresponding folder** in `DataManagementPlans/`
#    - This establishes a complete mapping between each document and its metadata context
#
# 4. **Check for feedback documents**
#    - Verify whether each DMP folder contains at least one feedback file (`.pdf`, `.doc`, or `.docx`) in its `feedback/` subfolder
#
# > If a feedback file exists, it can later be used for labeling.
# > If missing, feedback information may need to be extracted or inferred from the DMP content.

# %%
import os
import json
import shutil
from pathlib import Path
import re
import subprocess
from sklearn.model_selection import train_test_split
from typing import List, Dict, Tuple
import pandas as pd
from collections import Counter

# 1. setup paths and prepare directory structure

BASE_DIR = Path("/Users/JADEPOTTER5/Downloads/DMP-MT")
DMP_ROOT = BASE_DIR / "DataManagementPlans"
OUTPUT_DIR = BASE_DIR / "processed_data"
METADATA_FILE = BASE_DIR / "dmpmt.json" # metadata file

OUTPUT_DIRS = {
    "pdfs": OUTPUT_DIR / "pdfs", # original documents as pdf
    "docs": OUTPUT_DIR / "docs", # original documents as docx
    "parsed_files": OUTPUT_DIR / "parsed_files", # for parsed pdf files
    "splits": OUTPUT_DIR / "splits", # for train/test splits
}

# 2. Create output folders
for dir_path in OUTPUT_DIRS.values():
    dir_path.mkdir(parents=True, exist_ok=True)

# %%
# 3. Load metadata
with open(metadata_file, 'r') as f:
    metadata = json.load(f)

# Create a mapping from ID to metadata entry 
# Use the `LinkTitle` field (a unique ID) to **link metadata to its corresponding folder** in `DataManagementPlans/`  
metadata_map = {item['LinkTitle']: item for item in metadata}

# %%
# 4. Check whether the "feedback" document exists in the original folder DataManagementPlans.

def check_feedback_documents(root_path: Path):
    """Check each DMP folder for missing feedback documents (.pdf, .doc, .docx)."""
    print("\n[Check] Scanning for missing feedback documents...")

    missing = []
    total = 0

    for dmp_dir in root_path.iterdir():
        if not dmp_dir.is_dir():
            continue
        total += 1
        feedback_dir = dmp_dir / "feedback"

        if not feedback_dir.exists() or not any(feedback_dir.glob("*.pdf")) and not any(feedback_dir.glob("*.doc*")):
            missing.append(dmp_dir.name)

    print(f"\nTotal DMP folders: {total}")
    print(f"Missing feedback documents in: {len(missing)} folders:")
    for folder in missing:
        print(f"  - {folder}")

    return missing

# Example usage (run early in your main script)
missing_feedback_ids = check_feedback_documents(dmp_root)
# Out:
# [Check] Scanning for missing feedback documents...
#
# Total DMP folders: 2748
# Missing feedback documents in: 2748 folders:
#   - D-2024-2617
#   - D-2025-3643
#   - D-2022-1591
#   - D-2023-2292
#   - D-2024-3193
#   - D-2022-1565
#   - D-2024-3355
#   - D-2023-2266
#   - D-2024-2889
#   - D-2024-3167
#   - D-2023-2054
#   - D-2023-2430
#   - D-2024-3503
#   - D-2024-2842
#   - D-2024-2628
#   - D-2023-1870
#   - D-2025-3688
#   - D-2023-1884
#   - D-2021-1111
#   - D-2024-3158
#   - D-2021-1323
#   - D-2023-2259
#   - D-2023-2437
#   - D-2024-3504
#   - D-2021-1129
#   - D-2024-3160
#   - D-2023-2053
#   - D-2022-1562
#   - D-2024-3352
#   - D-2023-2261
#   - D-2024-3194
#   - D-2022-1596
#   - D-2023-2295
#   - D-2023-1848
#   - D-2024-2610
#   - D-2025-3644
#   - D-2021-1324
#   - D-2021-1116
#   - D-2023-2408
#   - D-2023-1883
#   - D-2023-1877
#   - D-2024-3399
#   - D-2024-2845
#   - D-2023-2098
#   - D-2023-2065
#   - D-2024-3156
#   - D-2023-2257
#   - D-2024-3364
#   - D-2022-1554
#   - D-2025-3686
#   - D-2024-3532
#   - D-2023-2401
#   - D-2025-3672
#   - D-2024-2626
#   - D-2023-2091
#   - D-2024-3390
#   - D-2021-1312
#   - D-2023-2268
#   - D-2021-1120
#   - D-2024-2887
#   - D-2024-3169
#   - D-2024-2873
#   - D-2023-1841
#   - D-2024-2619
#   - D-2024-3397
#   - D-2023-2096
#   - D-2025-3675
#   - D-2024-2621
#   - D-2023-1879
#   - D-2024-3535
#   - D-2023-2406
#   - D-2025-3681
#   - D-2023-2250
#   - D-2024-3363
#   - D-2022-1553
#   - D-2021-1118
#   - D-2023-2062
#   - D-2024-3151
#   - D-2023-1846
#   - D-2024-2874
#   - D-2022-1598
#   - D-2024-2880
#   - D-2021-1127
#   - D-2021-1315
#   - D-2023-2439
#   - D-2024-2478
#   - D-2023-1812
#   - D-2021-1187
#   - D-2024-2820
#   - D-2024-3308
#   - D-2021-1341
#   - D-2022-1538
#   - D-2023-2009
#   - D-2021-1173
#   - D-2025-3621
#   - D-2024-2675
#   - D-2024-2681
#   - D-2024-3561
#   - D-2023-2452
#   - D-2022-1351
#   - D-2023-2036
#   - D-2024-3105
#   - D-2022-1735
#   - D-2022-1507
#   - D-2023-2204
#   - D-2024-3337
#   - D-2022-1369
#   - D-2024-3559
#   - D-2021-1174
#   - D-2024-2827
#   - D-2021-1180
#   - D-2025-3619
#   - D-2023-1815
#   - D-2022-1500
#   - D-2023-2203
#   - D-2024-3330
#   - D-2023-2031
#   - D-2024-3102
#   - D-2022-1732
#   - D-2024-3566
#   - D-2023-2455
#   - D-2022-1356
#   - D-2024-2686
#   - D-2025-3626
#   - D-2024-2672
#   - D-2024-2818
#   - D-2023-2038
#   - D-2021-1142
#   - D-2022-1509
#   - D-2024-3339
#   - D-2023-1823
#   - D-2024-2811
#   - D-2022-1360
#   - D-2023-2463
#   - D-2024-3550
#   - D-2024-3306
#   - D-2023-2235
#   - D-2022-1536
#   - D-2022-1704
#   - D-2024-3134
#   - D-2023-2007
#   - D-2021-1189
#   - D-2022-1394
#   - D-2024-2644
#   - D-2025-3610
#   - D-2024-2816
#   - D-2023-1824
#   - D-2025-3628
#   - D-2024-3568
#   - D-2022-1358
#   - D-2024-2688
#   - D-2021-1145
#   - D-2024-2643
#   - D-2025-3617
#   - D-2022-1393
#   - D-2024-2829
#   - D-2022-1703
#   - D-2024-3133
#   - D-2023-2000
#   - D-2024-3301
#   - D-2023-2232
#   - D-2022-1531
#   - D-2022-1367
#   - D-2023-2464
#   - D-2024-2485
#   - D-2024-3557
#   - D-2025-3680
#   - D-2024-3534
#   - D-2023-2407
#   - D-2023-2063
#   - D-2024-3150
#   - D-2021-1119
#   - D-2023-2251
#   - D-2024-3362
#   - D-2022-1552
#   - D-2023-2097
#   - D-2024-3396
#   - D-2025-3674
#   - D-2024-2620
#   - D-2023-1878
#   - D-2021-1314
#   - D-2021-1126
#   - D-2024-2881
#   - D-2023-2438
#   - D-2023-1847
#   - D-2022-1599
#   - D-2024-2875
#   - D-2025-3673
#   - D-2024-2627
#   - D-2024-3391
#   - D-2023-2090
#   - D-2023-2256
#   - D-2024-3365
#   - D-2022-1555
#   - D-2023-2064
#   - D-2024-3157
#   - D-2024-3533
#   - D-2023-2400
#   - D-2025-3687
#   - D-2024-2872
#   - D-2023-1840
#   - D-2024-2618
#   - D-2024-3168
#   - D-2024-2886
#   - D-2023-2269
#   - D-2021-1313
#   - D-2022-1597
#   - D-2023-2294
#   - D-2024-3195
#   - D-2023-1849
#   - D-2024-2611
#   - D-2025-3645
#   - D-2023-2436
#   - D-2024-3505
#   - D-2022-1563
#   - D-2024-3353
#   - D-2023-2260
#   - D-2024-3161
#   - D-2023-2052
#   - D-2021-1128
#   - D-2023-1876
#   - D-2023-2099
#   - D-2024-2844
#   - D-2024-3398
#   - D-2021-1117
#   - D-2021-1325
#   - D-2023-1882
#   - D-2023-2409
#   - D-2024-3166
#   - D-2023-2055
#   - D-2022-1564
#   - D-2024-3354
#   - D-2023-2267
#   - D-2023-2431
#   - D-2024-3502
#   - D-2024-2616
#   - D-2025-3642
#   - D-2024-3192
#   - D-2022-1590
#   - D-2023-2293
#   - D-2025-3689
#   - D-2023-1885
#   - D-2023-2258
#   - D-2021-1322
#   - D-2024-3159
#   - D-2021-1110
#   - D-2024-2843
#   - D-2024-2629
#   - D-2023-1871
#   - D-2024-2689
#   - D-2024-3569
#   - D-2022-1359
#   - D-2021-1144
#   - D-2024-2817
#   - D-2023-1825
#   - D-2025-3629
#   - D-2024-3300
#   - D-2023-2233
#   - D-2022-1530
#   - D-2022-1702
#   - D-2024-3132
#   - D-2023-2001
#   - D-2022-1366
#   - D-2024-2484
#   - D-2023-2465
#   - D-2024-3556
#   - D-2022-1392
#   - D-2024-2642
#   - D-2025-3616
#   - D-2024-2828
#   - D-2023-1822
#   - D-2024-2810
#   - D-2022-1508
#   - D-2024-3338
#   - D-2021-1143
#   - D-2023-2039
#   - D-2021-1188
#   - D-2024-2645
#   - D-2025-3611
#   - D-2022-1395
#   - D-2022-1361
#   - D-2023-2462
#   - D-2024-2483
#   - D-2024-3551
#   - D-2022-1705
#   - D-2024-3135
#   - D-2023-2006
#   - D-2024-3307
#   - D-2023-2234
#   - D-2022-1537
#   - D-2021-1181
#   - D-2024-2826
#   - D-2025-3618
#   - D-2023-1814
#   - D-2022-1368
#   - D-2024-3558
#   - D-2021-1175
#   - D-2025-3627
#   - D-2024-2673
#   - D-2024-2819
#   - D-2023-2030
#   - D-2024-3103
#   - D-2022-1733
#   - D-2022-1501
#   - D-2023-2202
#   - D-2024-3331
#   - D-2024-2687
#   - D-2024-3567
#   - D-2023-2454
#   - D-2022-1357
#   - D-2021-1172
#   - D-2023-2008
#   - D-2021-1340
#   - D-2024-3309
#   - D-2022-1539
#   - D-2023-1813
#   - D-2024-2479
#   - D-2024-2821
#   - D-2021-1186
#   - D-2024-3560
#   - D-2023-2453
#   - D-2022-1350
#   - D-2024-2680
#   - D-2022-1506
#   - D-2023-2205
#   - D-2024-3336
#   - D-2023-2037
#   - D-2024-3104
#   - D-2022-1734
#   - D-2025-3620
#   - D-2024-2674
#   - D-2024-2534
#   - D-2025-3752
#   - D-2024-2706
#   - D-2022-1480
#   - D-2023-2383
#   - D-2024-3082
#   - D-2022-1474
#   - D-2023-2377
#   - D-2024-3244
#   - D-2023-2145
#   - D-2024-3076
#   - D-2024-2998
#   - D-2022-1646
#   - D-2024-3412
#   - D-2025-3594
#   - D-2024-2953
#   - D-2024-2739
#   - D-2023-1961
#   - D-2023-1995
#   - D-2022-1679
#   - D-2024-3049
#   - D-2021-1000
#   - D-2023-2348
#   - D-2021-1232
#   - D-2024-3415
#   - D-2025-3593
#   - D-2023-2142
#   - D-2024-3071
#   - D-2021-1038
#   - D-2022-1641
#   - D-2022-1473
#   - D-2023-2370
#   - D-2024-3243
#   - D-2024-3085
#   - D-2022-1487
#   - D-2023-2384
#   - D-2023-1959
#   - D-2025-3755
#   - D-2024-2701
#   - D-2024-2533
#   - D-2021-1235
#   - D-2021-1007
#   - D-2023-1992
#   - D-2023-1966
#   - D-2024-3288
#   - D-2023-2189
#   - D-2024-2954
#   - D-2022-1677
#   - D-2024-3047
#   - D-2023-2174
#   - D-2024-3275
#   - D-2023-2346
#   - D-2022-1445
#   - D-2024-3423
#   - D-2024-2737
#   - D-2025-3763
#   - D-2024-2505
#   - D-2022-1683
#   - D-2023-2180
#   - D-2024-3281
#   - D-2023-2379
#   - D-2021-1203
#   - D-2024-3078
#   - D-2024-2996
#   - D-2021-1031
#   - D-2022-1648
#   - D-2024-2962
#   - D-2023-1950
#   - D-2024-2708
#   - D-2024-3286
#   - D-2022-1684
#   - D-2023-2187
#   - D-2024-2730
#   - D-2025-3764
#   - D-2023-1968
#   - D-2024-3424
#   - D-2025-3790
#   - D-2024-3272
#   - D-2023-2341
#   - D-2022-1442
#   - D-2022-1670
#   - D-2024-3040
#   - D-2023-2173
#   - D-2021-1009
#   - D-2023-1957
#   - D-2024-2965
#   - D-2022-1489
#   - D-2021-1036
#   - D-2021-1204
#   - D-2024-2569
#   - D-2023-1903
#   - D-2023-1769
#   - D-2024-2931
#   - D-2021-1096
#   - D-2021-1250
#   - D-2024-3219
#   - D-2022-1429
#   - D-2021-1062
#   - D-2023-2118
#   - Forms
#   - D-2023-1756
#   - D-2024-2764
#   - D-2025-3730
#   - D-2024-2556
#   - D-2024-3484
#   - D-2024-2790
#   - D-2024-3470
#   - D-2024-3014
#   - D-2022-1624
#   - D-2022-1416
#   - D-2024-3226
#   - D-2023-2315
#   - D-2024-3448
#   - D-2021-1065
#   - D-2021-1257
#   - D-2021-1091
#   - D-2024-2936
#   - D-2025-3708
#   - D-2023-1904
#   - D-2022-1411
#   - D-2021-1268
#   - D-2024-3221
#   - D-2023-2312
#   - D-2024-3013
#   - D-2023-2120
#   - D-2022-1623
#   - D-2024-3477
#   - D-2024-2797
#   - D-2024-2551
#   - D-2024-3483
#   - D-2024-2763
#   - D-2025-3737
#   - D-2024-2909
#   - D-2023-1751
#   - D-2021-1053
#   - D-2023-2129
#   - D-2022-1418
#   - D-2021-1261
#   - D-2024-3228
#   - D-2023-1932
#   - D-2024-2558
#   - D-2024-2900
#   - D-2023-1758
#   - D-2021-1295
#   - D-2024-3441
#   - D-2024-2593
#   - D-2023-2324
#   - D-2024-3217
#   - D-2022-1427
#   - D-2023-1793
#   - D-2022-1615
#   - D-2023-2116
#   - D-2024-3025
#   - D-2023-1767
#   - D-2021-1098
#   - D-2024-2567
#   - D-2025-3701
#   - D-2024-2755
#   - D-2021-1292
#   - D-2024-2907
#   - D-2023-1935
#   - D-2025-3739
#   - D-2024-3479
#   - D-2024-2799
#   - D-2021-1266
#   - D-2021-1054
#   - D-2025-3706
#   - D-2024-2752
#   - D-2024-2560
#   - D-2023-1760
#   - D-2024-2938
#   - D-2023-1794
#   - D-2022-1612
#   - D-2023-2111
#   - D-2024-3022
#   - D-2021-1259
#   - D-2023-2323
#   - D-2024-3210
#   - D-2022-1420
#   - D-2024-3446
#   - D-2024-2594
#   - D-2025-3791
#   - D-2024-3425
#   - D-2022-1671
#   - D-2021-1008
#   - D-2024-3041
#   - D-2023-2172
#   - D-2024-3273
#   - D-2023-2340
#   - D-2022-1443
#   - D-2022-1685
#   - D-2023-2186
#   - D-2024-3287
#   - D-2024-2731
#   - D-2025-3765
#   - D-2023-1969
#   - D-2024-2503
#   - D-2021-1205
#   - D-2024-2990
#   - D-2021-1037
#   - D-2023-1956
#   - D-2022-1488
#   - D-2024-2964
#   - D-2024-2504
#   - D-2024-2736
#   - D-2025-3762
#   - D-2024-3280
#   - D-2022-1682
#   - D-2023-2181
#   - D-2024-3274
#   - D-2023-2347
#   - D-2022-1444
#   - D-2022-1676
#   - D-2024-3046
#   - D-2023-2175
#   - D-2024-3422
#   - D-2024-2963
#   - D-2023-1951
#   - D-2024-2709
#   - D-2021-1030
#   - D-2024-2997
#   - D-2024-3079
#   - D-2022-1649
#   - D-2021-1202
#   - D-2023-2378
#   - D-2022-1486
#   - D-2023-2385
#   - D-2024-3084
#   - D-2024-2532
#   - D-2023-1958
#   - D-2025-3754
#   - D-2024-2700
#   - D-2025-3592
#   - D-2024-3414
#   - D-2022-1472
#   - D-2023-2371
#   - D-2021-1039
#   - D-2023-2143
#   - D-2024-3070
#   - D-2022-1640
#   - D-2023-1967
#   - D-2024-2955
#   - D-2023-2188
#   - D-2024-3289
#   - D-2021-1006
#   - D-2021-1234
#   - D-2023-1993
#   - D-2024-2999
#   - D-2023-2144
#   - D-2024-3077
#   - D-2022-1647
#   - D-2022-1475
#   - D-2023-2376
#   - D-2024-3245
#   - D-2025-3595
#   - D-2024-3413
#   - D-2025-3753
#   - D-2024-2707
#   - D-2024-2535
#   - D-2024-3083
#   - D-2022-1481
#   - D-2023-2382
#   - D-2023-1994
#   - D-2021-1233
#   - D-2023-2349
#   - D-2022-1678
#   - D-2021-1001
#   - D-2024-3048
#   - D-2024-2952
#   - D-2024-2738
#   - D-2023-1960
#   - D-2024-2798
#   - D-2024-3478
#   - D-2021-1055
#   - D-2021-1267
#   - D-2024-2906
#   - D-2021-1293
#   - D-2023-1934
#   - D-2025-3738
#   - D-2023-2322
#   - D-2024-3211
#   - D-2021-1258
#   - D-2022-1421
#   - D-2022-1613
#   - D-2023-1795
#   - D-2023-2110
#   - D-2024-3447
#   - D-2024-2595
#   - D-2024-2561
#   - D-2025-3707
#   - D-2024-2753
#   - D-2023-1761
#   - D-2024-2939
#   - D-2024-2559
#   - D-2023-1933
#   - D-2021-1294
#   - D-2024-2901
#   - D-2023-1759
#   - D-2022-1419
#   - D-2024-3229
#   - D-2021-1260
#   - D-2023-2128
#   - D-2021-1052
#   - D-2023-1766
#   - D-2021-1099
#   - D-2025-3700
#   - D-2024-2754
#   - D-2024-2566
#   - D-2024-3440
#   - D-2024-2592
#   - D-2022-1614
#   - D-2023-2117
#   - D-2023-2325
#   - D-2024-3216
#   - D-2022-1426
#   - D-2024-2937
#   - D-2021-1090
#   - D-2025-3709
#   - D-2023-1905
#   - D-2024-3449
#   - D-2021-1256
#   - D-2021-1064
#   - D-2024-2762
#   - D-2025-3736
#   - D-2024-2550
#   - D-2024-3482
#   - D-2024-2908
#   - D-2023-1750
#   - D-2024-3012
#   - D-2023-2121
#   - D-2022-1622
#   - D-2022-1410
#   - D-2024-3220
#   - D-2023-2313
#   - D-2021-1269
#   - D-2024-2796
#   - D-2024-3476
#   - D-2023-2119
#   - D-2021-1063
#   - D-2024-3218
#   - D-2021-1251
#   - D-2022-1428
#   - D-2023-1902
#   - D-2024-2568
#   - D-2023-1768
#   - D-2021-1097
#   - D-2024-2930
#   - D-2024-3471
#   - D-2024-2791
#   - D-2022-1417
#   - D-2024-3227
#   - D-2023-2314
#   - D-2024-3015
#   - D-2023-2126
#   - D-2022-1625
#   - D-2023-1757
#   - D-2024-2557
#   - D-2024-3485
#   - D-2024-2765
#   - D-2025-3731
#   - D-2023-2104
#   - D-2024-3037
#   - D-2023-1781
#   - D-2022-1607
#   - D-2022-1435
#   - D-2023-2336
#   - D-2024-3205
#   - D-2024-3453
#   - D-2024-2581
#   - D-2025-3713
#   - D-2024-2747
#   - D-2024-2575
#   - D-2023-1775
#   - D-2023-2309
#   - D-2021-1273
#   - D-2022-1638
#   - D-2024-3008
#   - D-2021-1041
#   - D-2021-1287
#   - D-2024-2912
#   - D-2024-3498
#   - D-2024-2778
#   - D-2023-1920
#   - D-2023-1772
#   - D-2024-2572
#   - D-2023-1918
#   - D-2025-3714
#   - D-2024-2740
#   - D-2024-3454
#   - D-2024-2586
#   - D-2022-1432
#   - D-2023-2331
#   - D-2024-3202
#   - D-2023-2103
#   - D-2024-3030
#   - D-2021-1079
#   - D-2023-1786
#   - D-2022-1600
#   - D-2023-1927
#   - D-2024-2915
#   - D-2021-1280
#   - D-2021-1046
#   - D-2021-1274
#   - D-2024-2544
#   - D-2024-3496
#   - D-2024-2776
#   - D-2021-1289
#   - D-2024-3234
#   - D-2023-2307
#   - D-2022-1404
#   - D-2022-1636
#   - D-2023-2135
#   - D-2024-3462
#   - D-2024-2782
#   - D-2021-1084
#   - D-2024-2923
#   - D-2023-1911
#   - D-2024-2749
#   - D-2024-3039
#   - D-2021-1070
#   - D-2022-1609
#   - D-2023-2338
#   - D-2021-1242
#   - D-2024-2785
#   - D-2024-3465
#   - D-2022-1631
#   - D-2024-3001
#   - D-2023-2132
#   - D-2021-1048
#   - D-2024-3233
#   - D-2023-2300
#   - D-2022-1403
#   - D-2024-2771
#   - D-2025-3725
#   - D-2023-1929
#   - D-2024-2543
#   - D-2024-3491
#   - D-2021-1245
#   - D-2021-1077
#   - D-2023-1788
#   - D-2024-2588
#   - D-2023-1916
#   - D-2024-2924
#   - D-2021-1083
#   - D-2021-1023
#   - D-2024-2984
#   - D-2023-2159
#   - D-2021-1211
#   - D-2024-3258
#   - D-2022-1468
#   - D-2025-3588
#   - D-2023-1942
#   - D-2024-2528
#   - D-2024-2970
#   - D-2024-3431
#   - D-2023-1989
#   - D-2025-3785
#   - D-2022-1457
#   - D-2024-3267
#   - D-2023-2354
#   - D-2024-3055
#   - D-2023-2166
#   - D-2022-1665
#   - D-2024-3293
#   - D-2023-2192
#   - D-2022-1691
#   - D-2024-2725
#   - D-2025-3771
#   - D-2023-2398
#   - D-2024-2977
#   - D-2024-3099
#   - D-2025-3749
#   - D-2023-1945
#   - D-2024-3409
#   - D-2021-1216
#   - D-2024-2983
#   - D-2021-1024
#   - D-2024-2722
#   - D-2025-3776
#   - D-2024-2510
#   - D-2024-2948
#   - D-2023-2195
#   - D-2022-1696
#   - D-2024-3294
#   - D-2024-3052
#   - D-2023-2161
#   - D-2022-1662
#   - D-2022-1450
#   - D-2021-1229
#   - D-2024-3260
#   - D-2023-2353
#   - D-2025-3782
#   - D-2024-3436
#   - D-2024-2519
#   - D-2023-1973
#   - D-2024-2941
#   - D-2022-1459
#   - D-2021-1220
#   - D-2024-3269
#   - D-2021-1012
#   - D-2023-2168
#   - D-2023-1987
#   - D-2024-3090
#   - D-2023-2391
#   - D-2022-1492
#   - D-2025-3740
#   - D-2024-2714
#   - D-2024-2526
#   - D-2024-3400
#   - D-2022-1654
#   - D-2023-2157
#   - D-2024-3064
#   - D-2023-2365
#   - D-2024-3256
#   - D-2022-1466
#   - D-2023-1980
#   - D-2024-3438
#   - D-2021-1015
#   - D-2021-1227
#   - D-2024-2946
#   - D-2022-1698
#   - D-2023-1974
#   - D-2025-3778
#   - D-2021-1218
#   - D-2023-2362
#   - D-2024-3251
#   - D-2022-1461
#   - D-2022-1653
#   - D-2023-2150
#   - D-2024-3063
#   - D-2024-3407
#   - D-2024-2521
#   - D-2025-3747
#   - D-2024-2713
#   - D-2023-2396
#   - D-2022-1495
#   - D-2024-2979
#   - D-2024-3097
#   - D-2024-2542
#   - D-2024-3490
#   - D-2024-2770
#   - D-2025-3724
#   - D-2023-1928
#   - D-2024-3464
#   - D-2024-2784
#   - D-2024-3232
#   - D-2023-2301
#   - D-2022-1402
#   - D-2022-1630
#   - D-2021-1049
#   - D-2024-3000
#   - D-2023-2133
#   - D-2023-1917
#   - D-2021-1082
#   - D-2024-2925
#   - D-2021-1076
#   - D-2023-1789
#   - D-2021-1244
#   - D-2024-2589
#   - D-2022-1637
#   - D-2024-3007
#   - D-2023-2134
#   - D-2024-3235
#   - D-2023-2306
#   - D-2022-1405
#   - D-2024-2783
#   - D-2024-3463
#   - D-2024-2777
#   - D-2025-3723
#   - D-2024-2545
#   - D-2024-3497
#   - D-2021-1288
#   - D-2021-1243
#   - D-2023-2339
#   - D-2021-1071
#   - D-2024-3038
#   - D-2022-1608
#   - D-2024-2922
#   - D-2021-1085
#   - D-2023-1910
#   - D-2024-2748
#   - D-2024-3455
#   - D-2024-2587
#   - D-2021-1078
#   - D-2023-2102
#   - D-2024-3031
#   - D-2022-1601
#   - D-2023-1787
#   - D-2022-1433
#   - D-2023-2330
#   - D-2024-3203
#   - D-2023-1773
#   - D-2023-1919
#   - D-2025-3715
#   - D-2024-2741
#   - D-2024-2573
#   - D-2021-1275
#   - D-2021-1047
#   - D-2023-1926
#   - D-2021-1281
#   - D-2024-2914
#   - D-2024-2574
#   - D-2025-3712
#   - D-2024-2746
#   - D-2023-1774
#   - D-2022-1434
#   - D-2023-2337
#   - D-2024-3204
#   - D-2023-2105
#   - D-2024-3036
#   - D-2022-1606
#   - D-2023-1780
#   - D-2024-3452
#   - D-2024-2580
#   - D-2024-2913
#   - D-2021-1286
#   - D-2024-2779
#   - D-2023-1921
#   - D-2024-3499
#   - D-2022-1639
#   - D-2021-1040
#   - D-2024-3009
#   - D-2021-1272
#   - D-2023-2308
#   - D-2024-2947
#   - D-2022-1699
#   - D-2023-1975
#   - D-2025-3779
#   - D-2024-3439
#   - D-2023-1981
#   - D-2021-1226
#   - D-2021-1014
#   - D-2025-3746
#   - D-2024-2712
#   - D-2024-2520
#   - D-2024-3096
#   - D-2024-2978
#   - D-2023-2397
#   - D-2022-1494
#   - D-2022-1652
#   - D-2023-2151
#   - D-2024-3062
#   - D-2023-2363
#   - D-2024-3250
#   - D-2021-1219
#   - D-2022-1460
#   - D-2024-3406
#   - D-2023-2169
#   - D-2021-1013
#   - D-2022-1458
#   - D-2024-3268
#   - D-2021-1221
#   - D-2023-1986
#   - D-2023-1972
#   - D-2024-2940
#   - D-2024-3401
#   - D-2023-2364
#   - D-2024-3257
#   - D-2022-1467
#   - D-2022-1655
#   - D-2023-2156
#   - D-2024-3065
#   - D-2023-2390
#   - D-2022-1493
#   - D-2024-3091
#   - D-2024-2527
#   - D-2025-3741
#   - D-2024-2715
#   - D-2024-3408
#   - D-2021-1025
#   - D-2024-2982
#   - D-2021-1217
#   - D-2024-3098
#   - D-2024-2976
#   - D-2023-2399
#   - D-2025-3748
#   - D-2023-1944
#   - D-2022-1451
#   - D-2024-3261
#   - D-2023-2352
#   - D-2021-1228
#   - D-2024-3053
#   - D-2023-2160
#   - D-2022-1663
#   - D-2024-3437
#   - D-2025-3783
#   - D-2024-2511
#   - D-2024-2723
#   - D-2025-3777
#   - D-2024-3295
#   - D-2023-2194
#   - D-2024-2949
#   - D-2022-1697
#   - D-2024-2529
#   - D-2023-1943
#   - D-2024-2971
#   - D-2024-3259
#   - D-2021-1210
#   - D-2022-1469
#   - D-2023-2158
#   - D-2024-2985
#   - D-2021-1022
#   - D-2025-3589
#   - D-2023-2193
#   - D-2022-1690
#   - D-2024-3292
#   - D-2024-2724
#   - D-2025-3770
#   - D-2024-2516
#   - D-2023-1988
#   - D-2025-3784
#   - D-2024-3430
#   - D-2024-3054
#   - D-2023-2167
#   - D-2022-1664
#   - D-2022-1456
#   - D-2024-3266
#   - D-2023-2355
#   - D-2024-3126
#   - D-2023-2015
#   - D-2022-1716
#   - D-2022-1524
#   - D-2024-3314
#   - D-2023-2227
#   - D-2023-2471
#   - D-2024-2490
#   - D-2024-3542
#   - D-2022-1372
#   - D-2024-2656
#   - D-2025-3602
#   - D-2022-1386
#   - D-2023-2218
#   - D-2022-1729
#   - D-2021-1150
#   - D-2024-3119
#   - D-2024-2803
#   - D-2024-2669
#   - D-2023-1831
#   - D-2022-1381
#   - D-2023-1809
#   - D-2024-2651
#   - D-2025-3605
#   - D-2024-2497
#   - D-2023-2476
#   - D-2024-3545
#   - D-2022-1375
#   - D-2022-1523
#   - D-2024-3313
#   - D-2023-2220
#   - D-2021-1168
#   - D-2024-3121
#   - D-2023-2012
#   - D-2022-1711
#   - D-2023-1836
#   - D-2024-2804
#   - D-2021-1157
#   - D-2023-2449
#   - D-2024-3587
#   - D-2025-3633
#   - D-2024-2667
#   - D-2023-2216
#   - D-2024-3325
#   - D-2022-1515
#   - D-2022-1727
#   - D-2023-2024
#   - D-2024-3117
#   - D-2022-1343
#   - D-2024-3573
#   - D-2023-2440
#   - D-2024-2693
#   - D-2024-2832
#   - D-2021-1195
#   - D-2023-1800
#   - D-2024-2658
#   - D-2022-1388
#   - D-2021-1161
#   - D-2024-3128
#   - D-2022-1718
#   - D-2023-2229
#   - D-2024-2694
#   - D-2022-1344
#   - D-2024-3574
#   - D-2023-2447
#   - D-2022-1720
#   - D-2021-1159
#   - D-2023-2023
#   - D-2024-3110
#   - D-2023-2211
#   - D-2024-3322
#   - D-2022-1512
#   - D-2025-3634
#   - D-2024-2660
#   - D-2023-1838
#   - D-2024-3580
#   - D-2021-1166
#   - D-2023-1807
#   - D-2021-1192
#   - D-2024-2835
#   - D-2023-2048
#   - D-2024-2895
#   - D-2021-1132
#   - D-2024-3349
#   - D-2021-1300
#   - D-2022-1579
#   - D-2023-1853
#   - D-2024-2861
#   - D-2024-3520
#   - D-2023-2413
#   - D-2023-1898
#   - D-2025-3694
#   - D-2022-1546
#   - D-2023-2245
#   - D-2024-3376
#   - D-2023-2077
#   - D-2024-3144
#   - D-2024-3382
#   - D-2023-2083
#   - D-2025-3660
#   - D-2024-2634
#   - D-2023-2289
#   - D-2024-3188
#   - D-2024-2866
#   - D-2025-3658
#   - D-2023-1854
#   - D-2024-3518
#   - D-2021-1307
#   - D-2021-1135
#   - D-2024-2892
#   - D-2025-3667
#   - D-2024-2633
#   - D-2023-2084
#   - D-2024-2859
#   - D-2024-3385
#   - D-2023-2070
#   - D-2024-3143
#   - D-2022-1541
#   - D-2023-2242
#   - D-2024-3371
#   - D-2021-1338
#   - D-2025-3693
#   - D-2024-3527
#   - D-2023-2414
#   - D-2023-1862
#   - D-2024-2850
#   - D-2022-1548
#   - D-2024-3378
#   - D-2021-1331
#   - D-2023-2079
#   - D-2021-1103
#   - D-2023-1896
#   - D-2024-3181
#   - D-2023-2280
#   - D-2022-1583
#   - D-2024-2605
#   - D-2025-3651
#   - D-2023-2422
#   - D-2024-3511
#   - D-2022-1745
#   - D-2024-3175
#   - D-2023-2046
#   - D-2024-3347
#   - D-2023-2274
#   - D-2022-1577
#   - D-2023-1891
#   - D-2024-3529
#   - D-2021-1104
#   - D-2021-1336
#   - D-2024-2857
#   - D-2023-1865
#   - D-2025-3669
#   - D-2024-3340
#   - D-2023-2273
#   - D-2021-1309
#   - D-2022-1570
#   - D-2022-1742
#   - D-2024-3172
#   - D-2023-2041
#   - D-2023-2425
#   - D-2024-3516
#   - D-2024-2602
#   - D-2025-3656
#   - D-2023-2287
#   - D-2022-1584
#   - D-2024-3186
#   - D-2024-2868
#   - D-2024-3581
#   - D-2025-3635
#   - D-2024-2661
#   - D-2023-1839
#   - D-2022-1345
#   - D-2024-3575
#   - D-2023-2446
#   - D-2024-2695
#   - D-2023-2210
#   - D-2024-3323
#   - D-2022-1513
#   - D-2022-1721
#   - D-2023-2022
#   - D-2024-3111
#   - D-2021-1158
#   - D-2023-1806
#   - D-2024-2834
#   - D-2021-1193
#   - D-2021-1167
#   - D-2024-2498
#   - D-2022-1726
#   - D-2023-2025
#   - D-2024-3116
#   - D-2023-2217
#   - D-2024-3324
#   - D-2022-1514
#   - D-2024-2692
#   - D-2024-3572
#   - D-2023-2441
#   - D-2025-3632
#   - D-2024-2666
#   - D-2024-3586
#   - D-2023-2228
#   - D-2024-3129
#   - D-2021-1160
#   - D-2022-1719
#   - D-2021-1194
#   - D-2024-2833
#   - D-2022-1389
#   - D-2023-1801
#   - D-2024-2659
#   - D-2023-2477
#   - D-2024-2496
#   - D-2024-3544
#   - D-2022-1374
#   - D-2024-3120
#   - D-2023-2013
#   - D-2021-1169
#   - D-2022-1710
#   - D-2022-1522
#   - D-2024-3312
#   - D-2023-2221
#   - D-2023-1808
#   - D-2024-2650
#   - D-2025-3604
#   - D-2022-1380
#   - D-2021-1156
#   - D-2023-2448
#   - D-2023-1837
#   - D-2024-2805
#   - D-2022-1387
#   - D-2024-2657
#   - D-2025-3603
#   - D-2022-1525
#   - D-2024-3315
#   - D-2023-2226
#   - D-2023-2014
#   - D-2022-1717
#   - D-2024-2491
#   - D-2023-2470
#   - D-2024-3543
#   - D-2022-1373
#   - D-2024-2802
#   - D-2024-2668
#   - D-2023-1830
#   - D-2022-1728
#   - D-2024-3118
#   - D-2021-1151
#   - D-2023-2219
#   - D-2024-2856
#   - D-2023-1864
#   - D-2025-3668
#   - D-2024-3528
#   - D-2023-1890
#   - D-2021-1337
#   - D-2021-1105
#   - D-2024-2603
#   - D-2025-3657
#   - D-2024-2869
#   - D-2024-3187
#   - D-2023-2286
#   - D-2022-1585
#   - D-2022-1743
#   - D-2024-3173
#   - D-2023-2040
#   - D-2021-1308
#   - D-2024-3341
#   - D-2023-2272
#   - D-2022-1571
#   - D-2023-2424
#   - D-2024-3517
#   - D-2021-1102
#   - D-2023-2078
#   - D-2022-1549
#   - D-2021-1330
#   - D-2024-3379
#   - D-2023-1897
#   - D-2023-1863
#   - D-2024-2851
#   - D-2023-2423
#   - D-2024-3510
#   - D-2024-3346
#   - D-2023-2275
#   - D-2022-1576
#   - D-2022-1744
#   - D-2024-3174
#   - D-2023-2047
#   - D-2023-2281
#   - D-2022-1582
#   - D-2024-3180
#   - D-2024-2604
#   - D-2025-3650
#   - D-2024-3519
#   - D-2024-2893
#   - D-2021-1134
#   - D-2021-1306
#   - D-2024-2867
#   - D-2024-3189
#   - D-2023-2288
#   - D-2025-3659
#   - D-2023-1855
#   - D-2022-1540
#   - D-2021-1339
#   - D-2023-2243
#   - D-2024-3370
#   - D-2023-2071
#   - D-2024-3142
#   - D-2024-3526
#   - D-2023-2415
#   - D-2025-3692
#   - D-2025-3666
#   - D-2024-2632
#   - D-2024-3384
#   - D-2024-2858
#   - D-2023-2085
#   - D-2023-1852
#   - D-2024-2860
#   - D-2021-1301
#   - D-2024-3348
#   - D-2022-1578
#   - D-2021-1133
#   - D-2024-2894
#   - D-2023-2049
#   - D-2023-2082
#   - D-2024-3383
#   - D-2025-3661
#   - D-2024-2635
#   - D-2023-1899
#   - D-2025-3695
#   - D-2024-3521
#   - D-2023-2412
#   - D-2023-2076
#   - D-2024-3145
#   - D-2022-1547
#   - D-2023-2244
#   - D-2024-3377
#   - D-2024-2488
#   - D-2021-1177
#   - D-2024-2824
#   - D-2021-1183
#   - D-2023-1816
#   - D-2024-3101
#   - D-2023-2032
#   - D-2021-1148
#   - D-2022-1731
#   - D-2022-1503
#   - D-2024-3333
#   - D-2023-2200
#   - D-2024-2685
#   - D-2023-2456
#   - D-2024-3565
#   - D-2022-1355
#   - D-2023-1829
#   - D-2024-2671
#   - D-2025-3625
#   - D-2024-2649
#   - D-2023-1811
#   - D-2022-1399
#   - D-2021-1184
#   - D-2024-2823
#   - D-2022-1709
#   - D-2024-3139
#   - D-2021-1170
#   - D-2023-2238
#   - D-2021-1342
#   - D-2024-2676
#   - D-2025-3622
#   - D-2023-2451
#   - D-2024-3562
#   - D-2022-1352
#   - D-2024-2682
#   - D-2022-1504
#   - D-2024-3334
#   - D-2023-2207
#   - D-2024-3106
#   - D-2023-2035
#   - D-2022-1736
#   - D-2024-2815
#   - D-2023-1827
#   - D-2023-2458
#   - D-2021-1146
#   - D-2022-1390
#   - D-2025-3614
#   - D-2024-2640
#   - D-2023-1818
#   - D-2023-2231
#   - D-2024-3302
#   - D-2022-1532
#   - D-2022-1700
#   - D-2023-2003
#   - D-2024-3130
#   - D-2021-1179
#   - D-2022-1364
#   - D-2024-3554
#   - D-2023-2467
#   - D-2024-2486
#   - D-2023-2209
#   - D-2024-3108
#   - D-2021-1141
#   - D-2023-1820
#   - D-2024-2678
#   - D-2024-2812
#   - D-2022-1363
#   - D-2024-3553
#   - D-2024-2481
#   - D-2023-2460
#   - D-2022-1707
#   - D-2023-2004
#   - D-2024-3137
#   - D-2023-2236
#   - D-2024-3305
#   - D-2022-1535
#   - D-2025-3613
#   - D-2024-2647
#   - D-2022-1397
#   - D-2024-3507
#   - D-2023-2434
#   - D-2022-1561
#   - D-2021-1318
#   - D-2024-3351
#   - D-2023-2050
#   - D-2024-3163
#   - D-2022-1595
#   - D-2023-2296
#   - D-2024-2879
#   - D-2024-3197
#   - D-2025-3647
#   - D-2024-2613
#   - D-2021-1115
#   - D-2021-1327
#   - D-2023-1880
#   - D-2024-3538
#   - D-2025-3678
#   - D-2023-1874
#   - D-2024-2846
#   - D-2025-3640
#   - D-2024-2614
#   - D-2024-3190
#   - D-2022-1592
#   - D-2023-2291
#   - D-2023-2057
#   - D-2024-3164
#   - D-2022-1566
#   - D-2023-2265
#   - D-2024-3356
#   - D-2024-3500
#   - D-2023-2433
#   - D-2024-2841
#   - D-2023-1873
#   - D-2023-1887
#   - D-2021-1320
#   - D-2024-3369
#   - D-2022-1559
#   - D-2021-1112
#   - D-2023-2068
#   - D-2024-2848
#   - D-2024-3394
#   - D-2024-2622
#   - D-2025-3676
#   - D-2025-3682
#   - D-2023-2405
#   - D-2024-3536
#   - D-2024-3152
#   - D-2023-2061
#   - D-2021-1329
#   - D-2024-3360
#   - D-2023-2253
#   - D-2022-1550
#   - D-2023-1845
#   - D-2025-3649
#   - D-2023-2298
#   - D-2024-2877
#   - D-2024-3199
#   - D-2021-1316
#   - D-2024-2883
#   - D-2021-1124
#   - D-2024-3509
#   - D-2024-3367
#   - D-2023-2254
#   - D-2022-1557
#   - D-2024-3155
#   - D-2023-2066
#   - D-2023-2402
#   - D-2024-3531
#   - D-2025-3685
#   - D-2024-2625
#   - D-2025-3671
#   - D-2024-3393
#   - D-2023-2092
#   - D-2021-1123
#   - D-2024-2884
#   - D-2023-2059
#   - D-2022-1568
#   - D-2021-1311
#   - D-2024-3358
#   - D-2024-2870
#   - D-2023-1842
#   - D-2023-1821
#   - D-2024-2679
#   - D-2024-2813
#   - D-2021-1140
#   - D-2024-3109
#   - D-2022-1739
#   - D-2023-2208
#   - D-2022-1396
#   - D-2025-3612
#   - D-2024-2646
#   - D-2022-1362
#   - D-2024-3552
#   - D-2023-2461
#   - D-2024-2480
#   - D-2023-2237
#   - D-2024-3304
#   - D-2022-1534
#   - D-2022-1706
#   - D-2023-2005
#   - D-2024-3136
#   - D-2023-2459
#   - D-2021-1147
#   - D-2024-2814
#   - D-2023-1826
#   - D-2022-1701
#   - D-2021-1178
#   - D-2023-2002
#   - D-2024-3131
#   - D-2023-2230
#   - D-2024-3303
#   - D-2022-1533
#   - D-2022-1365
#   - D-2024-3555
#   - D-2024-2487
#   - D-2025-3615
#   - D-2024-2641
#   - D-2023-1819
#   - D-2022-1391
#   - D-2023-2239
#   - D-2022-1708
#   - D-2021-1171
#   - D-2024-3138
#   - D-2022-1398
#   - D-2024-2648
#   - D-2023-1810
#   - D-2024-2822
#   - D-2021-1185
#   - D-2024-2683
#   - D-2023-2450
#   - D-2024-3563
#   - D-2022-1353
#   - D-2024-3107
#   - D-2023-2034
#   - D-2022-1737
#   - D-2022-1505
#   - D-2024-3335
#   - D-2023-2206
#   - D-2024-2677
#   - D-2025-3623
#   - D-2021-1182
#   - D-2024-2825
#   - D-2023-1817
#   - D-2023-2468
#   - D-2024-2489
#   - D-2021-1176
#   - D-2023-1828
#   - D-2024-2670
#   - D-2025-3624
#   - D-2022-1502
#   - D-2024-3332
#   - D-2023-2201
#   - D-2021-1149
#   - D-2024-3100
#   - D-2023-2033
#   - D-2022-1730
#   - D-2023-2457
#   - D-2024-3564
#   - D-2022-1354
#   - D-2024-2684
#   - D-2024-2624
#   - D-2025-3670
#   - D-2023-2093
#   - D-2024-3392
#   - D-2024-3154
#   - D-2023-2067
#   - D-2024-3366
#   - D-2023-2255
#   - D-2022-1556
#   - D-2025-3684
#   - D-2023-1888
#   - D-2023-2403
#   - D-2024-3530
#   - D-2024-2871
#   - D-2023-1843
#   - D-2022-1569
#   - D-2024-3359
#   - D-2021-1310
#   - D-2023-2058
#   - D-2024-2885
#   - D-2021-1122
#   - D-2023-2404
#   - D-2024-3537
#   - D-2025-3683
#   - D-2024-3361
#   - D-2023-2252
#   - D-2021-1328
#   - D-2022-1551
#   - D-2024-3153
#   - D-2023-2060
#   - D-2024-3395
#   - D-2023-2094
#   - D-2024-2849
#   - D-2024-2623
#   - D-2025-3677
#   - D-2021-1125
#   - D-2024-2882
#   - D-2021-1317
#   - D-2024-3508
#   - D-2023-1844
#   - D-2025-3648
#   - D-2024-3198
#   - D-2024-2876
#   - D-2023-2299
#   - D-2022-1567
#   - D-2023-2264
#   - D-2024-3357
#   - D-2023-2056
#   - D-2024-3165
#   - D-2024-3501
#   - D-2023-2432
#   - D-2025-3641
#   - D-2024-2615
#   - D-2022-1593
#   - D-2023-2290
#   - D-2024-3191
#   - D-2023-1886
#   - D-2023-2069
#   - D-2021-1113
#   - D-2024-3368
#   - D-2021-1321
#   - D-2022-1558
#   - D-2024-2840
#   - D-2023-1872
#   - D-2024-3196
#   - D-2024-2878
#   - D-2022-1594
#   - D-2023-2297
#   - D-2025-3646
#   - D-2024-2612
#   - D-2024-3506
#   - D-2023-2435
#   - D-2023-2051
#   - D-2024-3162
#   - D-2023-2263
#   - D-2024-3350
#   - D-2021-1319
#   - D-2025-3679
#   - D-2023-1875
#   - D-2024-2847
#   - D-2021-1326
#   - D-2021-1114
#   - D-2024-3539
#   - D-2023-1881
#   - D-2024-2599
#   - D-2021-1254
#   - D-2023-1799
#   - D-2021-1066
#   - D-2021-1092
#   - D-2024-2935
#   - D-2023-1907
#   - D-2021-1059
#   - D-2023-2123
#   - D-2024-3010
#   - D-2022-1620
#   - D-2022-1412
#   - D-2023-2311
#   - D-2024-3222
#   - D-2024-2794
#   - D-2024-3474
#   - D-2023-1938
#   - D-2025-3734
#   - D-2024-2760
#   - D-2024-3480
#   - D-2024-2552
#   - D-2023-1752
#   - D-2024-2758
#   - D-2023-1900
#   - D-2024-2932
#   - D-2021-1095
#   - D-2022-1618
#   - D-2021-1061
#   - D-2024-3028
#   - D-2021-1253
#   - D-2023-2329
#   - D-2021-1298
#   - D-2023-1755
#   - D-2024-3487
#   - D-2024-2555
#   - D-2025-3733
#   - D-2024-2767
#   - D-2024-3473
#   - D-2024-2793
#   - D-2022-1415
#   - D-2023-2316
#   - D-2024-3225
#   - D-2023-2124
#   - D-2024-3017
#   - D-2022-1627
#   - D-2024-2904
#   - D-2021-1291
#   - D-2023-1936
#   - D-2021-1057
#   - D-2021-1265
#   - D-2024-2563
#   - D-2024-2751
#   - D-2025-3705
#   - D-2023-1909
#   - D-2023-1763
#   - D-2024-3213
#   - D-2023-2320
#   - D-2022-1423
#   - D-2022-1611
#   - D-2023-1797
#   - D-2021-1068
#   - D-2024-3021
#   - D-2023-2112
#   - D-2024-2597
#   - D-2024-3445
#   - D-2021-1262
#   - D-2023-2318
#   - D-2021-1050
#   - D-2024-3019
#   - D-2022-1629
#   - D-2024-3489
#   - D-2023-1931
#   - D-2024-2769
#   - D-2021-1296
#   - D-2024-2590
#   - D-2024-3442
#   - D-2022-1616
#   - D-2023-1790
#   - D-2024-3026
#   - D-2023-2115
#   - D-2024-3214
#   - D-2023-2327
#   - D-2022-1424
#   - D-2023-1764
#   - D-2024-2756
#   - D-2025-3702
#   - D-2024-2564
#   - D-2025-3590
#   - D-2024-3416
#   - D-2022-1470
#   - D-2024-3240
#   - D-2023-2373
#   - D-2021-1209
#   - D-2024-3072
#   - D-2023-2141
#   - D-2022-1642
#   - D-2022-1484
#   - D-2023-2387
#   - D-2024-3086
#   - D-2024-2968
#   - D-2024-2530
#   - D-2024-2702
#   - D-2025-3756
#   - D-2021-1004
#   - D-2021-1236
#   - D-2023-1991
#   - D-2024-3429
#   - D-2025-3769
#   - D-2023-1965
#   - D-2022-1689
#   - D-2024-2957
#   - D-2024-2705
#   - D-2025-3751
#   - D-2024-2537
#   - D-2024-3081
#   - D-2022-1483
#   - D-2023-2380
#   - D-2024-3075
#   - D-2023-2146
#   - D-2022-1645
#   - D-2022-1477
#   - D-2024-3247
#   - D-2023-2374
#   - D-2025-3597
#   - D-2024-3411
#   - D-2024-2950
#   - D-2024-2508
#   - D-2023-1962
#   - D-2023-1996
#   - D-2024-3278
#   - D-2021-1231
#   - D-2022-1448
#   - D-2023-2179
#   - D-2021-1003
#   - D-2022-1687
#   - D-2023-2184
#   - D-2024-2959
#   - D-2024-3285
#   - D-2025-3767
#   - D-2024-2733
#   - D-2024-2501
#   - D-2024-3427
#   - D-2023-2170
#   - D-2024-3043
#   - D-2023-2342
#   - D-2024-3271
#   - D-2021-1238
#   - D-2022-1441
#   - D-2023-1954
#   - D-2025-3758
#   - D-2023-2389
#   - D-2024-3088
#   - D-2024-2966
#   - D-2021-1207
#   - D-2021-1035
#   - D-2024-2992
#   - D-2024-3418
#   - D-2023-2345
#   - D-2024-3276
#   - D-2022-1446
#   - D-2022-1674
#   - D-2023-2177
#   - D-2024-3044
#   - D-2024-3420
#   - D-2023-1998
#   - D-2025-3760
#   - D-2024-2734
#   - D-2024-3282
#   - D-2022-1680
#   - D-2023-2183
#   - D-2025-3599
#   - D-2023-2148
#   - D-2024-2995
#   - D-2021-1032
#   - D-2022-1479
#   - D-2024-3249
#   - D-2021-1200
#   - D-2024-2961
#   - D-2023-1953
#   - D-2024-2539
#   - D-2023-1930
#   - D-2024-2768
#   - D-2024-3488
#   - D-2024-2902
#   - D-2021-1297
#   - D-2024-3018
#   - D-2021-1051
#   - D-2022-1628
#   - D-2023-2319
#   - D-2021-1263
#   - D-2023-1765
#   - D-2024-2565
#   - D-2024-2757
#   - D-2025-3703
#   - D-2024-2591
#   - D-2024-3443
#   - D-2023-2326
#   - D-2022-1425
#   - D-2023-1791
#   - D-2022-1617
#   - D-2024-3027
#   - D-2023-2114
#   - D-2021-1264
#   - D-2021-1056
#   - D-2021-1290
#   - D-2024-2905
#   - D-2023-1937
#   - D-2023-1796
#   - D-2022-1610
#   - D-2024-3020
#   - D-2023-2113
#   - D-2021-1069
#   - D-2024-3212
#   - D-2023-2321
#   - D-2022-1422
#   - D-2024-2596
#   - D-2024-3444
#   - D-2024-2750
#   - D-2025-3704
#   - D-2023-1908
#   - D-2024-2562
#   - D-2023-1762
#   - D-2023-2328
#   - D-2021-1252
#   - D-2022-1619
#   - D-2024-3029
#   - D-2021-1060
#   - D-2024-2759
#   - D-2023-1901
#   - D-2021-1094
#   - D-2024-2933
#   - D-2024-2792
#   - D-2024-3472
#   - D-2023-2125
#   - D-2024-3016
#   - D-2022-1626
#   - D-2022-1414
#   - D-2023-2317
#   - D-2024-3224
#   - D-2023-1754
#   - D-2021-1299
#   - D-2025-3732
#   - D-2024-2766
#   - D-2024-3486
#   - D-2024-2554
#   - D-2024-2934
#   - D-2021-1093
#   - D-2023-1906
#   - D-2024-2598
#   - D-2023-1798
#   - D-2021-1067
#   - D-2021-1255
#   - D-2024-3481
#   - D-2024-2553
#   - D-2023-1939
#   - D-2025-3735
#   - D-2024-2761
#   - D-2023-1753
#   - D-2022-1413
#   - D-2023-2310
#   - D-2024-3223
#   - D-2023-2122
#   - D-2024-3011
#   - D-2021-1058
#   - D-2022-1621
#   - D-2024-3475
#   - D-2024-2795
#   - D-2025-3761
#   - D-2024-2735
#   - D-2024-2507
#   - D-2022-1681
#   - D-2023-2182
#   - D-2024-3283
#   - D-2022-1675
#   - D-2023-2176
#   - D-2024-3045
#   - D-2023-2344
#   - D-2024-3277
#   - D-2022-1447
#   - D-2023-1999
#   - D-2024-3421
#   - D-2024-2960
#   - D-2024-2538
#   - D-2023-1952
#   - D-2025-3598
#   - D-2022-1478
#   - D-2021-1201
#   - D-2024-3248
#   - D-2021-1033
#   - D-2024-2994
#   - D-2023-2149
#   - D-2024-3426
#   - D-2025-3792
#   - D-2021-1239
#   - D-2023-2343
#   - D-2024-3270
#   - D-2022-1440
#   - D-2022-1672
#   - D-2023-2171
#   - D-2024-3042
#   - D-2024-3284
#   - D-2022-1686
#   - D-2024-2958
#   - D-2023-2185
#   - D-2024-2500
#   - D-2025-3766
#   - D-2024-2732
#   - D-2024-2993
#   - D-2021-1034
#   - D-2021-1206
#   - D-2024-3419
#   - D-2023-1955
#   - D-2025-3759
#   - D-2024-3089
#   - D-2023-2388
#   - D-2022-1476
#   - D-2024-3246
#   - D-2023-2375
#   - D-2024-3074
#   - D-2023-2147
#   - D-2022-1644
#   - D-2024-3410
#   - D-2025-3596
#   - D-2024-2536
#   - D-2024-2704
#   - D-2025-3750
#   - D-2022-1482
#   - D-2023-2381
#   - D-2024-3080
#   - D-2023-1997
#   - D-2021-1002
#   - D-2023-2178
#   - D-2021-1230
#   - D-2024-3279
#   - D-2022-1449
#   - D-2024-2951
#   - D-2023-1963
#   - D-2024-2509
#   - D-2024-2969
#   - D-2024-3087
#   - D-2022-1485
#   - D-2023-2386
#   - D-2024-2703
#   - D-2025-3757
#   - D-2024-2531
#   - D-2024-3417
#   - D-2025-3591
#   - D-2024-3073
#   - D-2023-2140
#   - D-2022-1643
#   - D-2022-1471
#   - D-2021-1208
#   - D-2024-3241
#   - D-2023-2372
#   - D-2025-3768
#   - D-2023-1964
#   - D-2022-1688
#   - D-2024-2956
#   - D-2021-1237
#   - D-2021-1005
#   - D-2024-3428
#   - D-2023-1990
#   - D-2022-1498
#   - D-2023-1946
#   - D-2024-2980
#   - D-2021-1027
#   - D-2021-1215
#   - D-2024-2513
#   - D-2023-1979
#   - D-2025-3775
#   - D-2024-2721
#   - D-2024-3297
#   - D-2023-2196
#   - D-2022-1695
#   - D-2022-1453
#   - D-2023-2350
#   - D-2024-3263
#   - D-2021-1018
#   - D-2023-2162
#   - D-2024-3051
#   - D-2022-1661
#   - D-2024-3435
#   - D-2025-3781
#   - D-2021-1212
#   - D-2023-2368
#   - D-2022-1659
#   - D-2021-1020
#   - D-2024-2987
#   - D-2024-3069
#   - D-2024-2719
#   - D-2023-1941
#   - D-2025-3786
#   - D-2024-3432
#   - D-2023-2165
#   - D-2024-3056
#   - D-2022-1666
#   - D-2022-1454
#   - D-2023-2357
#   - D-2024-3264
#   - D-2023-2191
#   - D-2022-1692
#   - D-2024-3290
#   - D-2025-3772
#   - D-2024-2726
#   - D-2023-1983
#   - D-2021-1224
#   - D-2021-1016
#   - D-2024-3299
#   - D-2024-2945
#   - D-2023-2198
#   - D-2023-1977
#   - D-2022-1650
#   - D-2021-1029
#   - D-2024-3060
#   - D-2023-2153
#   - D-2024-3252
#   - D-2023-2361
#   - D-2022-1462
#   - D-2024-3404
#   - D-2024-2710
#   - D-2025-3744
#   - D-2023-1948
#   - D-2024-2522
#   - D-2024-3094
#   - D-2023-2395
#   - D-2022-1496
#   - D-2023-1970
#   - D-2024-2728
#   - D-2024-2942
#   - D-2021-1011
#   - D-2024-3058
#   - D-2022-1668
#   - D-2021-1223
#   - D-2023-2359
#   - D-2023-1984
#   - D-2025-3788
#   - D-2023-2392
#   - D-2022-1491
#   - D-2024-3093
#   - D-2024-2717
#   - D-2025-3743
#   - D-2024-3403
#   - D-2024-3255
#   - D-2023-2366
#   - D-2022-1465
#   - D-2022-1657
#   - D-2024-2989
#   - D-2024-3067
#   - D-2023-2154
#   - D-2024-2929
#   - D-2023-1771
#   - D-2024-2743
#   - D-2025-3717
#   - D-2024-2571
#   - D-2024-2585
#   - D-2024-3457
#   - D-2024-3033
#   - D-2023-2100
#   - D-2022-1603
#   - D-2023-1785
#   - D-2022-1431
#   - D-2024-3201
#   - D-2023-2332
#   - D-2021-1248
#   - D-2025-3728
#   - D-2023-1924
#   - D-2021-1283
#   - D-2024-2916
#   - D-2021-1277
#   - D-2021-1045
#   - D-2024-3468
#   - D-2024-2788
#   - D-2022-1436
#   - D-2024-3206
#   - D-2023-2335
#   - D-2024-3034
#   - D-2023-2107
#   - D-2022-1604
#   - D-2023-1782
#   - D-2024-2582
#   - D-2024-3450
#   - D-2024-2576
#   - D-2024-2744
#   - D-2025-3710
#   - D-2021-1089
#   - D-2023-1776
#   - D-2023-2138
#   - D-2021-1042
#   - D-2024-3239
#   - D-2021-1270
#   - D-2022-1409
#   - D-2023-1749
#   - D-2024-2911
#   - D-2021-1284
#   - D-2023-1923
#   - D-2024-2549
#   - D-2024-3466
#   - D-2024-2786
#   - D-2023-2303
#   - D-2024-3230
#   - D-2021-1279
#   - D-2022-1400
#   - D-2022-1632
#   - D-2023-2131
#   - D-2024-3002
#   - D-2024-2918
#   - D-2024-3492
#   - D-2024-2540
#   - D-2025-3726
#   - D-2024-2772
#   - D-2021-1074
#   - D-2021-1246
#   - D-2024-3459
#   - D-2023-1915
#   - D-2025-3719
#   - D-2024-2927
#   - D-2021-1080
#   - D-2025-3721
#   - D-2024-2775
#   - D-2024-3495
#   - D-2024-2547
#   - D-2023-1747
#   - D-2022-1635
#   - D-2023-2136
#   - D-2023-2304
#   - D-2024-3237
#   - D-2022-1407
#   - D-2024-2781
#   - D-2024-3461
#   - D-2021-1087
#   - D-2024-2920
#   - D-2023-1778
#   - D-2024-2578
#   - D-2023-1912
#   - D-2022-1438
#   - D-2024-3208
#   - D-2021-1241
#   - D-2023-2109
#   - D-2021-1073
#   - D-2023-2358
#   - D-2021-1222
#   - D-2024-3059
#   - D-2021-1010
#   - D-2022-1669
#   - D-2023-1985
#   - D-2025-3789
#   - D-2023-1971
#   - D-2024-2729
#   - D-2024-2943
#   - D-2024-3402
#   - D-2022-1656
#   - D-2024-3066
#   - D-2023-2155
#   - D-2024-2988
#   - D-2024-3254
#   - D-2023-2367
#   - D-2022-1464
#   - D-2024-3092
#   - D-2023-2393
#   - D-2022-1490
#   - D-2024-2716
#   - D-2025-3742
#   - D-2024-2524
#   - D-2023-2199
#   - D-2024-2944
#   - D-2024-3298
#   - D-2023-1976
#   - D-2023-1982
#   - D-2021-1017
#   - D-2021-1225
#   - D-2024-2523
#   - D-2024-2711
#   - D-2025-3745
#   - D-2023-1949
#   - D-2023-2394
#   - D-2022-1497
#   - D-2024-3095
#   - D-2024-3253
#   - D-2023-2360
#   - D-2022-1463
#   - D-2022-1651
#   - D-2024-3061
#   - D-2023-2152
#   - D-2021-1028
#   - D-2024-3405
#   - D-2024-2718
#   - D-2023-1940
#   - D-2024-2972
#   - D-2022-1658
#   - D-2024-3068
#   - D-2021-1021
#   - D-2023-2369
#   - D-2021-1213
#   - D-2024-3291
#   - D-2023-2190
#   - D-2022-1693
#   - D-2024-2515
#   - D-2025-3773
#   - D-2024-2727
#   - D-2024-3433
#   - D-2025-3787
#   - D-2022-1455
#   - D-2023-2356
#   - D-2024-3265
#   - D-2023-2164
#   - D-2024-3057
#   - D-2022-1667
#   - D-2021-1214
#   - D-2021-1026
#   - D-2022-1499
#   - D-2024-2975
#   - D-2023-1947
#   - D-2023-2163
#   - D-2024-3050
#   - D-2021-1019
#   - D-2022-1660
#   - D-2022-1452
#   - D-2023-2351
#   - D-2024-3262
#   - D-2025-3780
#   - D-2024-3434
#   - D-2023-1978
#   - D-2025-3774
#   - D-2024-2720
#   - D-2024-2512
#   - D-2023-2197
#   - D-2022-1694
#   - D-2024-3296
#   - D-2023-2305
#   - D-2024-3236
#   - D-2022-1406
#   - D-2022-1634
#   - D-2023-2137
#   - D-2024-3460
#   - D-2024-2780
#   - D-2024-3494
#   - D-2024-2546
#   - D-2025-3720
#   - D-2024-2774
#   - D-2021-1072
#   - D-2023-2108
#   - D-2022-1439
#   - D-2021-1240
#   - D-2024-3209
#   - D-2024-2921
#   - D-2021-1086
#   - D-2023-1779
#   - D-2023-1913
#   - D-2024-2579
#   - D-2024-2919
#   - D-2025-3727
#   - D-2024-2773
#   - D-2024-3493
#   - D-2024-2541
#   - D-2024-2787
#   - D-2024-3467
#   - D-2022-1633
#   - D-2023-2130
#   - D-2021-1278
#   - D-2023-2302
#   - D-2024-3231
#   - D-2022-1401
#   - D-2023-1914
#   - D-2025-3718
#   - D-2021-1081
#   - D-2024-2926
#   - D-2021-1247
#   - D-2021-1075
#   - D-2024-3458
#   - D-2024-2745
#   - D-2025-3711
#   - D-2024-2577
#   - D-2021-1088
#   - D-2023-1777
#   - D-2024-3035
#   - D-2023-2106
#   - D-2023-1783
#   - D-2022-1605
#   - D-2022-1437
#   - D-2024-3207
#   - D-2023-2334
#   - D-2024-2583
#   - D-2024-3451
#   - D-2023-1748
#   - D-2024-2910
#   - D-2024-2548
#   - D-2023-1922
#   - D-2021-1271
#   - D-2024-3238
#   - D-2022-1408
#   - D-2021-1043
#   - D-2023-2139
#   - D-2024-2584
#   - D-2024-3456
#   - D-2022-1430
#   - D-2021-1249
#   - D-2024-3200
#   - D-2023-2333
#   - D-2024-3032
#   - D-2023-2101
#   - D-2023-1784
#   - D-2022-1602
#   - D-2024-2928
#   - D-2023-1770
#   - D-2024-2570
#   - D-2024-2742
#   - D-2025-3716
#   - D-2021-1044
#   - D-2021-1276
#   - D-2024-2789
#   - D-2024-3469
#   - D-2025-3729
#   - D-2023-1925
#   - D-2024-2917
#   - D-2021-1282
#   - D-2024-2865
#   - D-2022-1589
#   - D-2023-1857
#   - D-2023-2428
#   - D-2021-1136
#   - D-2024-2891
#   - D-2021-1304
#   - D-2023-1868
#   - D-2024-2630
#   - D-2025-3664
#   - D-2024-3386
#   - D-2023-2087
#   - D-2022-1542
#   - D-2024-3372
#   - D-2023-2241
#   - D-2024-3140
#   - D-2023-2073
#   - D-2021-1109
#   - D-2023-2417
#   - D-2024-3524
#   - D-2025-3690
#   - D-2023-2279
#   - D-2021-1303
#   - D-2024-3178
#   - D-2024-2896
#   - D-2021-1131
#   - D-2024-2608
#   - D-2023-1850
#   - D-2024-2862
#   - D-2025-3697
#   - D-2023-2410
#   - D-2024-3523
#   - D-2024-3147
#   - D-2023-2074
#   - D-2022-1545
#   - D-2024-3375
#   - D-2023-2246
#   - D-2023-2080
#   - D-2024-3381
#   - D-2024-2637
#   - D-2025-3663
#   - D-2023-2419
#   - D-2023-1892
#   - D-2021-1335
#   - D-2021-1107
#   - D-2024-3388
#   - D-2023-2089
#   - D-2024-2854
#   - D-2023-1866
#   - D-2022-1741
#   - D-2023-2042
#   - D-2024-3171
#   - D-2021-1138
#   - D-2023-2270
#   - D-2024-3343
#   - D-2022-1573
#   - D-2024-3515
#   - D-2023-2426
#   - D-2025-3655
#   - D-2024-2601
#   - D-2023-1859
#   - D-2024-3185
#   - D-2023-2284
#   - D-2022-1587
#   - D-2023-1861
#   - D-2024-2639
#   - D-2024-2853
#   - D-2024-3149
#   - D-2021-1100
#   - D-2023-2248
#   - D-2021-1332
#   - D-2023-1895
#   - D-2025-3699
#   - D-2023-2283
#   - D-2022-1580
#   - D-2024-3182
#   - D-2025-3652
#   - D-2024-2606
#   - D-2024-3512
#   - D-2023-2421
#   - D-2023-2277
#   - D-2024-3344
#   - D-2022-1574
#   - D-2022-1746
#   - D-2023-2045
#   - D-2024-3176
#   - D-2024-2838
#   - D-2025-3606
#   - D-2024-2652
#   - D-2022-1382
#   - D-2024-3546
#   - D-2023-2475
#   - D-2022-1376
#   - D-2023-2011
#   - D-2024-3122
#   - D-2022-1712
#   - D-2022-1520
#   - D-2023-2223
#   - D-2025-3639
#   - D-2023-1835
#   - D-2024-2807
#   - D-2021-1154
#   - D-2022-1349
#   - D-2024-3579
#   - D-2024-2699
#   - D-2022-1527
#   - D-2023-2224
#   - D-2024-3317
#   - D-2023-2016
#   - D-2024-3125
#   - D-2022-1715
#   - D-2024-3541
#   - D-2023-2472
#   - D-2024-2493
#   - D-2022-1371
#   - D-2022-1385
#   - D-2025-3601
#   - D-2024-2655
#   - D-2021-1198
#   - D-2021-1153
#   - D-2023-2029
#   - D-2024-3328
#   - D-2022-1518
#   - D-2024-2800
#   - D-2023-1832
#   - D-2022-1347
#   - D-2023-2444
#   - D-2024-3577
#   - D-2024-2697
#   - D-2024-3321
#   - D-2023-2212
#   - D-2022-1511
#   - D-2022-1723
#   - D-2024-3113
#   - D-2023-2020
#   - D-2024-2809
#   - D-2024-3583
#   - D-2024-2663
#   - D-2025-3637
#   - D-2021-1165
#   - D-2024-3548
#   - D-2022-1378
#   - D-2023-1804
#   - D-2025-3608
#   - D-2021-1191
#   - D-2024-2836
#   - D-2024-2664
#   - D-2025-3630
#   - D-2024-3584
#   - D-2022-1724
#   - D-2024-3114
#   - D-2023-2027
#   - D-2024-3326
#   - D-2023-2215
#   - D-2022-1516
#   - D-2024-2690
#   - D-2023-2443
#   - D-2024-3570
#   - D-2024-2831
#   - D-2021-1196
#   - D-2022-1529
#   - D-2024-3319
#   - D-2021-1162
#   - D-2023-2018
#   - D-2021-1333
#   - D-2023-2249
#   - D-2021-1101
#   - D-2024-3148
#   - D-2023-1894
#   - D-2025-3698
#   - D-2023-1860
#   - D-2024-2638
#   - D-2024-2852
#   - D-2024-3513
#   - D-2023-2420
#   - D-2024-2899
#   - D-2023-2044
#   - D-2024-3177
#   - D-2023-2276
#   - D-2024-3345
#   - D-2022-1575
#   - D-2024-3183
#   - D-2023-2282
#   - D-2022-1581
#   - D-2025-3653
#   - D-2024-2607
#   - D-2024-2855
#   - D-2023-2088
#   - D-2024-3389
#   - D-2023-1867
#   - D-2023-1893
#   - D-2023-2418
#   - D-2021-1106
#   - D-2021-1334
#   - D-2025-3654
#   - D-2024-2600
#   - D-2023-1858
#   - D-2023-2285
#   - D-2022-1586
#   - D-2024-3184
#   - D-2023-2271
#   - D-2024-3342
#   - D-2022-1572
#   - D-2022-1740
#   - D-2021-1139
#   - D-2023-2043
#   - D-2024-3170
#   - D-2024-3514
#   - D-2023-2427
#   - D-2024-2609
#   - D-2023-1851
#   - D-2024-2863
#   - D-2021-1130
#   - D-2024-2897
#   - D-2024-3179
#   - D-2021-1302
#   - D-2024-3380
#   - D-2023-2081
#   - D-2024-2636
#   - D-2025-3662
#   - D-2023-2411
#   - D-2024-3522
#   - D-2025-3696
#   - D-2022-1544
#   - D-2024-3374
#   - D-2023-2247
#   - D-2024-3146
#   - D-2023-2075
#   - D-2023-2429
#   - D-2021-1305
#   - D-2024-2890
#   - D-2021-1137
#   - D-2022-1588
#   - D-2024-2864
#   - D-2023-1856
#   - D-2021-1108
#   - D-2024-3141
#   - D-2023-2072
#   - D-2022-1543
#   - D-2024-3373
#   - D-2023-2240
#   - D-2025-3691
#   - D-2023-2416
#   - D-2024-3525
#   - D-2023-1869
#   - D-2024-2631
#   - D-2025-3665
#   - D-2023-2086
#   - D-2024-3387
#   - D-2024-3327
#   - D-2023-2214
#   - D-2022-1517
#   - D-2022-1725
#   - D-2024-3115
#   - D-2023-2026
#   - D-2023-2442
#   - D-2024-2691
#   - D-2024-3585
#   - D-2024-2665
#   - D-2025-3631
#   - D-2023-2019
#   - D-2021-1163
#   - D-2022-1528
#   - D-2024-3318
#   - D-2021-1197
#   - D-2024-2830
#   - D-2023-1802
#   - D-2024-2808
#   - D-2024-2662
#   - D-2025-3636
#   - D-2024-2696
#   - D-2022-1346
#   - D-2023-2445
#   - D-2024-3576
#   - D-2022-1722
#   - D-2024-3112
#   - D-2023-2021
#   - D-2024-3320
#   - D-2023-2213
#   - D-2022-1510
#   - D-2023-1805
#   - D-2025-3609
#   - D-2024-2837
#   - D-2021-1164
#   - D-2024-3549
#   - D-2022-1379
#   - D-2025-3600
#   - D-2024-2654
#   - D-2022-1384
#   - D-2021-1199
#   - D-2023-2017
#   - D-2024-3124
#   - D-2022-1714
#   - D-2022-1526
#   - D-2023-2225
#   - D-2024-3316
#   - D-2024-3540
#   - D-2024-2492
#   - D-2023-2473
#   - D-2022-1370
#   - D-2024-2801
#   - D-2023-1833
#   - D-2024-3329
#   - D-2022-1519
#   - D-2023-2028
#   - D-2021-1152
#   - D-2024-3547
#   - D-2023-2474
#   - D-2024-2495
#   - D-2022-1377
#   - D-2022-1521
#   - D-2023-2222
#   - D-2024-3311
#   - D-2023-2010
#   - D-2024-3123
#   - D-2022-1713
#   - D-2024-2839
#   - D-2022-1383
#   - D-2025-3607
#   - D-2024-2653
#   - D-2021-1155
#   - D-2024-2698
#   - D-2022-1348
#   - D-2024-3578
#   - D-2025-3638
#   - D-2023-1834
#   - D-2024-2806

# %% [markdown]
# ### Step 2: Standardize All Initial Files into PDFs
#
# To ensure consistency in processing, we standardize all Initial documents into PDF format. These documents may initially appear as `.pdf`, `.doc`, or `.docx` files. This step involves:
#
# 1. **Collecting Initial Documents**
#    - Search each ID folder for files located in the `Initial/` subfolder.
#    - Identify and record `.pdf`, `.doc`, or `.docx` files.
#
# 2. **Organizing Files**
#    - Copy all collected files from `DataManagementPlans/` into a new processing directory `processed_data/`.
#      - Separate files by format:
#        - PDFs → `processed_data/pdfs/`
#        - Word documents (`.doc` and `.docx`) → `processed_data/docs/`
#      - Link them with Metadata by their corresponding ID (`LinkTitle`).
#
# 3. **Converting Word Docs to PDF and Restructuring**
#    - Use **LibreOffice** (`soffice`) in headless mode to convert `.doc` and `.docx` files to PDF.
#    - Converted files are saved directly into `processed_data/pdfs_new/converted_pdf/`.
#    - Original `.pdf` files are moved into `processed_data/pdfs_new/org_pdfs/`.
#    - This results in a unified folder structure:
#
#      ```
#      processed_data/
#      └── pdfs_new/
#          ├── org_pdfs/         # Original PDFs
#          └── converted_pdf/    # PDFs converted from Word files
#      ```
#
#    This creates a clean separation between original and converted formats for downstream processing.

# %%
# 1. Scan all ID folders and collect supported Initial documents (PDF, DOC, DOCX).

def collect_initial_files(root_path):
    file_records = []
    for id_dir in root_path.iterdir():
        if id_dir.is_dir():
            initial_dir = id_dir / "Initial"
            if initial_dir.exists():
                # find all PDF files in the Initial directory
                for pdf_file in initial_dir.glob("*.pdf"):
                    file_records.append({
                        'LinkTitle': id_dir.name,
                        'file_path': pdf_file,
                        'file_type': 'pdf'
                    })
                
                # find all DOC and DOCX files in the Initial directory
                for doc_file in initial_dir.glob("*.doc"):
                    file_records.append({
                        'LinkTitle': id_dir.name,
                        'file_path': doc_file,
                        'file_type': 'doc'
                    })
                for docx_file in initial_dir.glob("*.docx"):
                    file_records.append({
                        'LinkTitle': id_dir.name,
                        'file_path': docx_file,
                        'file_type': 'docx'
                    })
    return file_records

initial_files = collect_initial_files(dmp_root)
print(f"find {len(initial_files)} Initial files（PDF and DOC/DOCX）")
# Out:
# find 2409 Initial files（PDF and DOC/DOCX）

# %%
# 2. Copy all collected files from `DataManagementPlans/` into a new processing directory `processed_data/` and link metadata to each file.

# Ensure output_dir is a Path object
output_dir = Path(output_dir)

valid_files = []
for file_record in initial_files:
    file_id = file_record['LinkTitle']
    src_path = file_record['file_path']
    file_type = file_record['file_type']

    # Check if the file ID exists in the metadata map
    if file_id not in metadata_map:
        print(f"Warning: {file_id} not found in metadata. Skipping.")
        continue

    # Create destination directory based on file type
    if file_type == 'pdf':
        dest_dir = output_dir / "pdfs"
        dest_dir.mkdir(parents=True, exist_ok=True)  # Make sure directory exists
        dest_filename = f"{file_id}.pdf"
    else:  # doc/docx
        dest_dir = output_dir / "docs"
        dest_dir.mkdir(parents=True, exist_ok=True)  # Make sure directory exists
        dest_filename = f"{file_id}.{file_type}"

    dest_path = dest_dir / dest_filename

    try:
        shutil.copy(src_path, dest_path)
        valid_files.append({
            'LinkTitle': file_id,
            'file_type': file_type,
            'file_path': str(dest_path.relative_to(output_dir)),
            'metadata': metadata_map[file_id]  # link metadata
        })
    except Exception as e:
        print(f"Failed to copy file {src_path}: {e}")

print(f"Successfully processed {len(valid_files)} files")
# Out:
# Successfully processed 2409 files

# %%
# 3. Convert all DOC/DOCX files to PDF using LibreOffice in headless mode.

# Set up base directory
output_dir = Path("/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data")

# Define new output structure
new_pdfs_dir = output_dir / "pdfs_new"
org_pdfs_dir = new_pdfs_dir / "org_pdfs"
converted_pdf_dir = new_pdfs_dir / "converted_pdf"

# Create directories if they don't exist
org_pdfs_dir.mkdir(parents=True, exist_ok=True)
converted_pdf_dir.mkdir(parents=True, exist_ok=True)

# --- Step 1: Convert DOC/DOCX to PDF ---
def convert_docs_to_pdf(output_dir, valid_files, converted_pdf_dir):
    success = []
    failed = []

    for file_info in valid_files:
        file_id = file_info['LinkTitle']
        file_type = file_info['file_type']

        if file_type in ['doc', 'docx']:
            src_path = output_dir / file_info['file_path']
            dest_pdf_path = converted_pdf_dir / f"{file_id}.pdf"

            print(f"🌀 Converting: {src_path}")
            convert_cmd = f'soffice --headless --convert-to pdf --outdir "{converted_pdf_dir}" "{src_path}"'
            print(f"📄 Running command: {convert_cmd}")

            try:
                subprocess.run(convert_cmd, shell=True, check=True)

                if dest_pdf_path.exists():
                    print(f"✅ Successfully converted to PDF: {file_id}")
                    success.append(file_id)
                else:
                    print(f"❌ Conversion failed (file not found): {file_id}")
                    failed.append(file_id)

            except subprocess.CalledProcessError as e:
                print(f"❌ Conversion command error: {file_id}, Error: {e}")
                failed.append(file_id)

    # Summary log
    print("\n📊 DOC/DOCX → PDF conversion results:")
    print(f"✅ Success: {len(success)} files")
    print(f"❌ Failed: {len(failed)} files")
    if failed:
        print("🚨 Failed file IDs:")
        for fid in failed:
            print(f"- {fid}")

    return success, failed

# --- Step 2: Move existing original PDFs to new folder ---
def move_original_pdfs(output_dir, org_pdfs_dir):
    pdfs_dir = output_dir / "pdfs"
    if pdfs_dir.exists():
        print(f"\n📦 Moving original PDFs from {pdfs_dir} to {org_pdfs_dir}")
        for item in pdfs_dir.iterdir():
            shutil.move(str(item), org_pdfs_dir)
        pdfs_dir.rmdir()  # Remove old folder if empty
        print("✅ Original PDFs moved.")
    else:
        print("⚠️ No original PDF folder found to move.")


# --- Run the steps ---
# Example: `valid_files` should be defined earlier with file info dictionaries
# valid_files = [{'LinkTitle': 'filename1', 'file_type': 'doc', 'file_path': 'relative/path/to/file.doc'}, ...]

successfully_converted, failed_converted = convert_docs_to_pdf(output_dir, valid_files, converted_pdf_dir)
move_original_pdfs(output_dir, org_pdfs_dir)

print(f"\n🎉 All done! New folder structure is under:\n{new_pdfs_dir}")
# Out:
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2628.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2628.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2628.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2628.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2628.pdf
# ✅ Successfully converted to PDF: D-2024-2628
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3158.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3158.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3158.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3158.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3158.pdf
# ✅ Successfully converted to PDF: D-2024-3158
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1323.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1323.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1323.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1323.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1323.pdf
# ✅ Successfully converted to PDF: D-2021-1323
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3352.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3352.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3352.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3352.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3352.pdf
# ✅ Successfully converted to PDF: D-2024-3352
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2261.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2261.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2261.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2261.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2261.pdf
# ✅ Successfully converted to PDF: D-2023-2261
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3194.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3194.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3194.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3194.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3194.pdf
# ✅ Successfully converted to PDF: D-2024-3194
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1116.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1116.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1116.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1116.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1116.pdf
# ✅ Successfully converted to PDF: D-2021-1116
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3390.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3390.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3390.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3390.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3390.pdf
# ✅ Successfully converted to PDF: D-2024-3390
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2887.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2887.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2887.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2887.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2887.pdf
# ✅ Successfully converted to PDF: D-2024-2887
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3169.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3169.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3169.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3169.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3169.pdf
# ✅ Successfully converted to PDF: D-2024-3169
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1841.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1841.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1841.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1841.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1841.pdf
# ✅ Successfully converted to PDF: D-2023-1841
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2619.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2619.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2619.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2619.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2619.pdf
# ✅ Successfully converted to PDF: D-2024-2619
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2096.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2096.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2096.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2096.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2096.pdf
# ✅ Successfully converted to PDF: D-2023-2096
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1118.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1118.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1118.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1118.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1118.pdf
# ✅ Successfully converted to PDF: D-2021-1118
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2874.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2874.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2874.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2874.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2874.pdf
# ✅ Successfully converted to PDF: D-2024-2874
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1127.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1127.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1127.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1127.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1127.pdf
# ✅ Successfully converted to PDF: D-2021-1127
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2439.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2439.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2439.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2439.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2439.pdf
# ✅ Successfully converted to PDF: D-2023-2439
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2820.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2820.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2820.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2820.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2820.pdf
# ✅ Successfully converted to PDF: D-2024-2820
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3621.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3621.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3621.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3621.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3621.pdf
# ✅ Successfully converted to PDF: D-2025-3621
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2675.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2675.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2675.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2675.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2675.pdf
# ✅ Successfully converted to PDF: D-2024-2675
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3561.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3561.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3561.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3561.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3561.pdf
# ✅ Successfully converted to PDF: D-2024-3561
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1369.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1369.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1369.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1369.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1369.pdf
# ✅ Successfully converted to PDF: D-2022-1369
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2827.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2827.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2827.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2827.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2827.pdf
# ✅ Successfully converted to PDF: D-2024-2827
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2203.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2203.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2203.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2203.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2203.pdf
# ✅ Successfully converted to PDF: D-2023-2203
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2031.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2031.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2031.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2031.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2031.pdf
# ✅ Successfully converted to PDF: D-2023-2031
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2672.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2672.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2672.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2672.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2672.pdf
# ✅ Successfully converted to PDF: D-2024-2672
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1704.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1704.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1704.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1704.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1704.pdf
# ✅ Successfully converted to PDF: D-2022-1704
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2688.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2688.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2688.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2688.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2688.pdf
# ✅ Successfully converted to PDF: D-2024-2688
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1145.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1145.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1145.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1145.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1145.pdf
# ✅ Successfully converted to PDF: D-2021-1145
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2643.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2643.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2643.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2643.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2643.pdf
# ✅ Successfully converted to PDF: D-2024-2643
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3133.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3133.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3133.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3133.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3133.pdf
# ✅ Successfully converted to PDF: D-2024-3133
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2464.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2464.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2464.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2464.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2464.pdf
# ✅ Successfully converted to PDF: D-2023-2464
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2251.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2251.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2251.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2251.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2251.pdf
# ✅ Successfully converted to PDF: D-2023-2251
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2881.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2881.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2881.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2881.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2881.pdf
# ✅ Successfully converted to PDF: D-2024-2881
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1847.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1847.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1847.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1847.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1847.pdf
# ✅ Successfully converted to PDF: D-2023-1847
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2627.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2627.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2627.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2627.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2627.pdf
# ✅ Successfully converted to PDF: D-2024-2627
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2256.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2256.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2256.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2256.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2256.pdf
# ✅ Successfully converted to PDF: D-2023-2256
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3157.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3157.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3157.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3157.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3157.pdf
# ✅ Successfully converted to PDF: D-2024-3157
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2436.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2436.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2436.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2436.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2436.pdf
# ✅ Successfully converted to PDF: D-2023-2436
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2260.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2260.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2260.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2260.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2260.pdf
# ✅ Successfully converted to PDF: D-2023-2260
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2844.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2844.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2844.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2844.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2844.pdf
# ✅ Successfully converted to PDF: D-2024-2844
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3166.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3166.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3166.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3166.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3166.pdf
# ✅ Successfully converted to PDF: D-2024-3166
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3354.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3354.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3354.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3354.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3354.pdf
# ✅ Successfully converted to PDF: D-2024-3354
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2267.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2267.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2267.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2267.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2267.pdf
# ✅ Successfully converted to PDF: D-2023-2267
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1871.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1871.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1871.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1871.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1871.pdf
# ✅ Successfully converted to PDF: D-2023-1871
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2689.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2689.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2689.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2689.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2689.pdf
# ✅ Successfully converted to PDF: D-2024-2689
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2233.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2233.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2233.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2233.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2233.pdf
# ✅ Successfully converted to PDF: D-2023-2233
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2001.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2001.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2001.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2001.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2001.pdf
# ✅ Successfully converted to PDF: D-2023-2001
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2642.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2642.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2642.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2642.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2642.pdf
# ✅ Successfully converted to PDF: D-2024-2642
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1508.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1508.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1508.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1508.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1508.pdf
# ✅ Successfully converted to PDF: D-2022-1508
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1537.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1537.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1537.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1537.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1537.pdf
# ✅ Successfully converted to PDF: D-2022-1537
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2826.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2826.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2826.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2826.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2826.pdf
# ✅ Successfully converted to PDF: D-2024-2826
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1175.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1175.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1175.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1175.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1175.pdf
# ✅ Successfully converted to PDF: D-2021-1175
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2673.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2673.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2673.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2673.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2673.pdf
# ✅ Successfully converted to PDF: D-2024-2673
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3567.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3567.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3567.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3567.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3567.pdf
# ✅ Successfully converted to PDF: D-2024-3567
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1340.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1340.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1340.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1340.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1340.pdf
# ✅ Successfully converted to PDF: D-2021-1340
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1813.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1813.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1813.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1813.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1813.pdf
# ✅ Successfully converted to PDF: D-2023-1813
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2453.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2453.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2453.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2453.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2453.pdf
# ✅ Successfully converted to PDF: D-2023-2453
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1734.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1734.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1734.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1734.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1734.pdf
# ✅ Successfully converted to PDF: D-2022-1734
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2534.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2534.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2534.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2534.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2534.pdf
# ✅ Successfully converted to PDF: D-2024-2534
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2377.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2377.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2377.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2377.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2377.pdf
# ✅ Successfully converted to PDF: D-2023-2377
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1995.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1995.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1995.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1995.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1995.pdf
# ✅ Successfully converted to PDF: D-2023-1995
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1000.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1000.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2021-1000.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1000.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1000.pdf
# ✅ Successfully converted to PDF: D-2021-1000
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2142.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2142.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2142.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2142.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2142.pdf
# ✅ Successfully converted to PDF: D-2023-2142
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1992.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1992.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1992.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1992.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1992.pdf
# ✅ Successfully converted to PDF: D-2023-1992
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2954.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2954.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2954.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2954.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2954.pdf
# ✅ Successfully converted to PDF: D-2024-2954
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2505.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2505.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2505.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2505.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2505.pdf
# ✅ Successfully converted to PDF: D-2024-2505
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1683.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1683.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1683.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1683.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1683.pdf
# ✅ Successfully converted to PDF: D-2022-1683
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2180.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2180.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2180.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2180.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2180.pdf
# ✅ Successfully converted to PDF: D-2023-2180
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2708.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2708.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2708.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2708.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2708.pdf
# ✅ Successfully converted to PDF: D-2024-2708
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2187.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2187.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2187.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2187.pdf using filter : writer_pdf_Export
# ...
# ✅ Successfully converted to PDF: D-2021-1137
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3141.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3141.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3141.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3141.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3141.pdf
# ✅ Successfully converted to PDF: D-2024-3141
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1543.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1543.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1543.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1543.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1543.pdf
# ✅ Successfully converted to PDF: D-2022-1543
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2240.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2240.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2240.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2240.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2240.pdf
# ✅ Successfully converted to PDF: D-2023-2240
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2086.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2086.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2086.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2086.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2086.pdf
# ✅ Successfully converted to PDF: D-2023-2086
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3327.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3327.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3327.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3327.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3327.pdf
# ✅ Successfully converted to PDF: D-2024-3327
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1725.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1725.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1725.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1725.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1725.pdf
# ✅ Successfully converted to PDF: D-2022-1725
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1802.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1802.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1802.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1802.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1802.pdf
# ✅ Successfully converted to PDF: D-2023-1802
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3636.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3636.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3636.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3636.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3636.pdf
# ✅ Successfully converted to PDF: D-2025-3636
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3112.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3112.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3112.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3112.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3112.pdf
# ✅ Successfully converted to PDF: D-2024-3112
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3320.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3320.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3320.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3320.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3320.pdf
# ✅ Successfully converted to PDF: D-2024-3320
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2213.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2213.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-2213.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2213.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2213.pdf
# ✅ Successfully converted to PDF: D-2023-2213
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1379.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1379.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1379.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1379.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1379.pdf
# ✅ Successfully converted to PDF: D-2022-1379
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2654.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2654.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2654.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2654.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2654.pdf
# ✅ Successfully converted to PDF: D-2024-2654
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2492.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2492.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2492.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2492.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2492.pdf
# ✅ Successfully converted to PDF: D-2024-2492
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2495.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2495.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-2495.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2495.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2495.pdf
# ✅ Successfully converted to PDF: D-2024-2495
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3123.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3123.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2024-3123.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3123.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3123.pdf
# ✅ Successfully converted to PDF: D-2024-3123
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1713.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1713.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2022-1713.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1713.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1713.pdf
# ✅ Successfully converted to PDF: D-2022-1713
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3607.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3607.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2025-3607.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3607.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3607.pdf
# ✅ Successfully converted to PDF: D-2025-3607
# 🌀 Converting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1834.docx
# 📄 Running command: soffice --headless --convert-to pdf --outdir "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf" "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1834.docx"
# convert /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/docs/D-2023-1834.docx as a Writer document -> /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1834.pdf using filter : writer_pdf_Export
# Overwriting: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1834.pdf
# ✅ Successfully converted to PDF: D-2023-1834
#
# 📊 DOC/DOCX → PDF conversion results:
# ✅ Success: 504 files
# ❌ Failed: 0 files
#
# 📦 Moving original PDFs from /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs to /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb Cell 8 in <cell line: 75>()
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=69'>70</a> # --- Run the steps ---
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=70'>71</a> # Example: `valid_files` should be defined earlier with file info dictionaries
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=71'>72</a> # valid_files = [{'LinkTitle': 'filename1', 'file_type': 'doc', 'file_path': 'relative/path/to/file.doc'}, ...]
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=73'>74</a> successfully_converted, failed_converted = convert_docs_to_pdf(output_dir, valid_files, converted_pdf_dir)
# ---> <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=74'>75</a> move_original_pdfs(output_dir, org_pdfs_dir)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=76'>77</a> print(f"\n🎉 All done! New folder structure is under:\n{new_pdfs_dir}")
#
# /Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb Cell 8 in move_original_pdfs(output_dir, org_pdfs_dir)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=60'>61</a> print(f"\n📦 Moving original PDFs from {pdfs_dir} to {org_pdfs_dir}")
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=61'>62</a> for item in pdfs_dir.iterdir():
# ---> <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=62'>63</a>     shutil.move(str(item), org_pdfs_dir)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=63'>64</a> pdfs_dir.rmdir()  # Remove old folder if empty
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#W5sZmlsZQ%3D%3D?line=64'>65</a> print("✅ Original PDFs moved.")
#
# File ~/opt/anaconda3/lib/python3.9/shutil.py:821, in move(src, dst, copy_function)
#     818     real_dst = os.path.join(dst, _basename(src))
#     820     if os.path.exists(real_dst):
# --> 821         raise Error("Destination path '%s' already exists" % real_dst)
#     822 try:
#     823     os.rename(src, real_dst)
#
# Error: Destination path '/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2021-1060.pdf' already exists

# %% [markdown]
# ### Step 3: Convert All PDFs to JSON (Unstructured)
#
# This step processes all original and converted PDF files into json files for downstream analysis. It includes three sub-steps: single file conversion, batch processing, and validation.
#
# 1. Convert a Single PDF to JSON:Use this step to test or debug the conversion of one PDF file before running batch processing.
# 2. Batch Convert All PDFs to JSON: This script recursively finds all .pdf files in a base folder and converts them to .json, applying basic text cleanup.
# 3. Verification step to list PDFs that did not successfully convert to JSON.

# %%
# 1. Parse the single PDF file and convert it to JSON format

from PyPDF2 import PdfReader

def extract_full_text(pdf_path):
    """
    Extract the full text content from a PDF file.
    """
    with open(pdf_path, 'rb') as file:
        reader = PdfReader(file)
        full_text = "\n".join(page.extract_text() or "" for page in reader.pages)
    return full_text

def pdf_to_single_json(pdf_path, output_dir):
    """
    Convert a single PDF file into a JSON format (with true section titles), and save it to the specified directory.
    """
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    document_id = os.path.splitext(os.path.basename(pdf_path))[0]
    output_json_path = os.path.join(output_dir, f"{document_id}.structured.json")
    
    pdf_info = {
        "document_id": document_id,
        "LinkTitle": document_id,
        "file_name": os.path.basename(pdf_path),
        "file_path": pdf_path,
        "metadata": {},
        "content": {
            "full_text": "",
        }
    }
    
    try:
        # Read the PDF file and extract structured content
        with open(pdf_path, 'rb') as file:
            reader = PdfReader(file)
            
            # Extract metadata
            pdf_info["metadata"] = {
                "title": reader.metadata.title or document_id,
                "author": reader.metadata.author or "N/A",
                "creation_date": str(reader.metadata.creation_date) if reader.metadata.creation_date else "N/A",
                "num_pages": len(reader.pages)
            }
            
        # Extract full text
        pdf_info["content"]["full_text"] = extract_full_text(pdf_path)
        
        # Save as JSON file
        with open(output_json_path, 'w', encoding='utf-8') as json_file:
            json.dump(pdf_info, json_file, indent=4, ensure_ascii=False)
        
        print(f"Successfully converted: {pdf_path} -> {output_json_path}")
    
    except Exception as e:
        print(f"Failed to process {pdf_path}: {str(e)}")

# Test call
pdf_path = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2021-1002.pdf"
output_dir = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files"

pdf_to_single_json(pdf_path, output_dir)

# %%
# 2. Parse all PDFs in a directory and convert them to JSON format

# Directory configuration
base_pdf_dir = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new"
output_dir = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files"

# Character replacement mapping for cleaning extracted text
REPLACEMENTS = {
    "â€˜": "'", "â€™": "'",
    "â€œ": '"', "â€�": '"',
    "â€“": "-", "â€”": "—",
    "â€¢": "•", "â€¦": "...",
    "Ã©": "é", "Ã": "à", "Â": ""
}

def clean_text(text):
    """
    Replace known character encoding issues and normalize whitespace.
    """
    for bad, good in REPLACEMENTS.items():
        text = text.replace(bad, good)
    return re.sub(r'\s+', ' ', text).strip()

def extract_full_text(pdf_path):
    """
    Extract full text from all pages of a PDF file.
    """
    with open(pdf_path, 'rb') as f:
        reader = PdfReader(f)
        return "\n".join(page.extract_text() or "" for page in reader.pages)

def process_pdf(pdf_path):
    """
    Process a single PDF: extract metadata, clean text, and return JSON-ready dict.
    """
    doc_id = os.path.splitext(os.path.basename(pdf_path))[0]
    try:
        with open(pdf_path, 'rb') as f:
            reader = PdfReader(f)
            metadata = reader.metadata

            full_text = extract_full_text(pdf_path)
            clean = clean_text(full_text)

            return {
                "document_id": doc_id,
                "LinkTitle": doc_id,
                "file_name": os.path.basename(pdf_path),
                "file_path": pdf_path,
                "metadata": {
                    "title": metadata.title if metadata and metadata.title else doc_id,
                    "author": metadata.author if metadata and metadata.author else "N/A",
                    "num_pages": len(reader.pages)
                },
                "content": {
                    "full_text": full_text
                },
                "clean_full_text": clean
            }, doc_id

    except Exception as e:
        print(f"❌ Failed to process {pdf_path}: {e}")
        return None, None

def batch_convert_pdfs(input_dir, output_dir):
    """
    Walk through the input directory, convert all PDFs to cleaned JSON files.
    """
    os.makedirs(output_dir, exist_ok=True)
    total, success = 0, 0

    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith('.pdf'):
                total += 1
                pdf_path = os.path.join(root, file)
                print(f"📄 Processing: {pdf_path}")

                data, doc_id = process_pdf(pdf_path)
                if data:
                    out_path = os.path.join(output_dir, f"{doc_id}.json")
                    with open(out_path, 'w', encoding='utf-8') as f:
                        json.dump(data, f, indent=4, ensure_ascii=False)
                    print(f"✅ Saved: {out_path}")
                    success += 1

    print(f"\n📊 Completed. Total: {total}, Successful: {success}")

if __name__ == "__main__":
    batch_convert_pdfs(base_pdf_dir, output_dir)
# Out:
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1972.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1972.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1074.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1074.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2260.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2260.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3443.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3443.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2985.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2985.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2248.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2248.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2761.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2761.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3133.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3133.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1543.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1543.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1557.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1557.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1316.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1316.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3053.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3053.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1379.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1379.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2826.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2826.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3245.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3245.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2300.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2300.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2601.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2601.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2615.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2615.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1621.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1621.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2301.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2301.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2628.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2628.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3522.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3522.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1813.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1813.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3287.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3287.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2827.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2827.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1387.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1387.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1542.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1542.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2589.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2589.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2261.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2261.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1061.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1061.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2951.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2951.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2979.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2979.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1795.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1795.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2992.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2992.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2776.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2776.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2548.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2548.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2049.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2049.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1540.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1540.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1385.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1385.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1329.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1329.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1391.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1391.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2101.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2101.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3520.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3520.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3246.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3246.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1623.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1623.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2458.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2458.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3253.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3253.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2464.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2464.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1116.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1116.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3284.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3284.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1435.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1435.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1353.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1353.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3737.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3737.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1541.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1541.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2993.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2993.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3333.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3333.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3327.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3327.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2987.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2987.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2289.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2289.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3496.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3496.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2299.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2299.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1948.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1948.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2798.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2798.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1960.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1960.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2954.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2954.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2272.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2272.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3445.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3445.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1586.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1586.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1551.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1551.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2571.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2571.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1545.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1545.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1425.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1425.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3280.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3280.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2820.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2820.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2613.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2613.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1627.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1627.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2448.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2448.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2460.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2460.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2461.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2461.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2612.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2612.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2835.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2835.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3295.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3295.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2809.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2809.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1424.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1424.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2558.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2558.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2570.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2570.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2564.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2564.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1593.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1593.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3450.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3450.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2267.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2267.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1098.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1098.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1746.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1746.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3493.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3493.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1949.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1949.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1988.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1988.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3320.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3320.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3446.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3446.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2067.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2067.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2823.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2823.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1630.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1630.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3268.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3268.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3240.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3240.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1619.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1619.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2639.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2639.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2836.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2836.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1802.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1802.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1369.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1369.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1433.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1433.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3123.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3123.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2567.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2567.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1272.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1272.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2765.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2765.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1070.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1070.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1786.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1786.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2931.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2931.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1939.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1939.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2203.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2203.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3434.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3434.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3352.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3352.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3420.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3420.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3408.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3408.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1736.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1736.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2528.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2528.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2001.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2001.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1508.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1508.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3636.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3636.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1534.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1534.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3756.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3756.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3742.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3742.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2149.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2149.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1871.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1871.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2689.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2689.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2377.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2377.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2439.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2439.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2676.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2676.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1657.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1657.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3233.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3233.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3555.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3555.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2887.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2887.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2878.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2878.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2688.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2688.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2844.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2844.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3596.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3596.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2148.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2148.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2160.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2160.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3145.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3145.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3623.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3623.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1214.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1214.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1737.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1737.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3409.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3409.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1938.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1938.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3384.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3384.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1910.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1910.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3390.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3390.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1014.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1014.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1000.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1000.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1709.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1709.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3345.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3345.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2200.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2200.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1216.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1216.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1202.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1202.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2002.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2002.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3621.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3621.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1537.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1537.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2503.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2503.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1523.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1523.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2162.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2162.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1872.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1872.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2360.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2360.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3225.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3225.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2675.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2675.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2661.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2661.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1899.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1899.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3224.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3224.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1683.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1683.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1175.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1175.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1873.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1873.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3032.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3032.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1720.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1720.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2229.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2229.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3378.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3378.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1734.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1734.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1708.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1708.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1001.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1001.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1039.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1039.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1011.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1011.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1903.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1903.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1917.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1917.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1005.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1005.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1730.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1730.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3368.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3368.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1724.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1724.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3354.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3354.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1485.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1485.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1491.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1491.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3036.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3036.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1888.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1888.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2670.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2670.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2664.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2664.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2365.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2365.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3552.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3552.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2658.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2658.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2881.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2881.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2895.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2895.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2671.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2671.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1484.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1484.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3157.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3157.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3625.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3625.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1533.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1533.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3194.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3194.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1719.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1719.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3427.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3427.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2238.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2238.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1725.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1725.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3382.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3382.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2908.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2908.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1012.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1012.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3419.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3419.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2206.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2206.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3431.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3431.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3343.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3343.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3196.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3196.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3169.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3169.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2505.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2505.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3141.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3141.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1451.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1451.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3035.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3035.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3747.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3747.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3592.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3592.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2667.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2667.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2673.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2673.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2414.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2414.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3237.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3237.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2896.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2896.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2367.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2367.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2882.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2882.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2672.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2672.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1875.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1875.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3034.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3034.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2171.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2171.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1444.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1444.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3791.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3791.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1493.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1493.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2538.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2538.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2504.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2504.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2022-1524.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1524.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3197.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3197.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-2213.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2213.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2921.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2921.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1901.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1901.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1930.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1930.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2023-1918.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1918.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-3401.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3401.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2723.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2723.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2509.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2509.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2024-2521.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2521.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2021-1340.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1340.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/converted_pdf/D-2025-3788.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3788.json
# ...
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1469.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1469.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2025-3757.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2025-3757.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2174.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2174.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1482.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1482.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1496.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1496.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2028.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2028.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2501.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2501.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1535.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1535.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3179.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3179.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1521.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1521.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2515.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2515.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2014.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2014.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1509.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1509.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3151.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3151.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2000.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2000.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2529.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2529.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2021-1228.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1228.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3186.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3186.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2021-1200.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1200.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2703.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2703.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2717.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2717.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1723.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1723.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2216.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2216.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2202.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2202.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3435.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3435.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3353.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3353.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2918.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2918.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2021-1016.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1016.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2924.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2924.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-1904.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1904.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2930.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2930.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2021-1002.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1002.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-1906.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1906.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2926.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2926.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3386.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3386.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3392.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3392.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2932.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2932.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-1912.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-1912.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2021-1028.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2021-1028.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2214.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2214.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2729.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2729.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2228.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2228.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2701.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2701.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1735.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1735.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2022-1721.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2022-1721.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-2715.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-2715.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3184.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3184.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3190.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3190.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3147.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3147.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2023-2016.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2023-2016.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2024-3153.pdf
# ✅ 转换并保存: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files/D-2024-3153.json
# 处理文件: /Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new/org_pdfs/D-2025-3782.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb Cell 10 in <cell line: 93>()
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=90'>91</a>     print(f"\n完成：共处理 {total} 个文件，成功 {success} 个。")
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=92'>93</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=93'>94</a>     batch_convert_pdfs(base_pdf_dir, output_dir)
#
# /Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb Cell 10 in batch_convert_pdfs(input_root, output_folder)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=81'>82</a> pdf_path = os.path.join(root, file)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=82'>83</a> print(f"处理文件: {pdf_path}")
# ---> <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=83'>84</a> json_data, doc_id = process_pdf(pdf_path)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=84'>85</a> if json_data and doc_id:
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=85'>86</a>     output_path = os.path.join(output_folder, f"{doc_id}.json")
#
# /Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb Cell 10 in process_pdf(pdf_path)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=57'>58</a>     meta = reader.metadata
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=58'>59</a>     pdf_info["metadata"] = {
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=59'>60</a>         "title": meta.title if meta and meta.title else document_id,
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=60'>61</a>         "author": meta.author if meta and meta.author else "N/A",
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=61'>62</a>         "num_pages": len(reader.pages)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=62'>63</a>     }
# ---> <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=64'>65</a> pdf_info["content"]["full_text"] = extract_full_text(pdf_path)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=65'>66</a> pdf_info['clean_full_text'] = clean_text(pdf_info["content"]["full_text"])
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=67'>68</a> return pdf_info, document_id
#
# /Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb Cell 10 in extract_full_text(pdf_path)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=32'>33</a> with open(pdf_path, 'rb') as file:
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=33'>34</a>     reader = PdfReader(file)
# ---> <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=34'>35</a>     full_text = "\n".join(page.extract_text() or "" for page in reader.pages)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=35'>36</a> return full_text
#
# /Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb Cell 10 in <genexpr>(.0)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=32'>33</a> with open(pdf_path, 'rb') as file:
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=33'>34</a>     reader = PdfReader(file)
# ---> <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=34'>35</a>     full_text = "\n".join(page.extract_text() or "" for page in reader.pages)
#      <a href='vscode-notebook-cell:/Users/JADEPOTTER5/Downloads/DMP-MT/data_processing.ipynb#X16sZmlsZQ%3D%3D?line=35'>36</a> return full_text
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/PyPDF2/_page.py:1851, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1848 if isinstance(orientations, int):
#    1849     orientations = (orientations,)
# -> 1851 return self._extract_text(
#    1852     self,
#    1853     self.pdf,
#    1854     orientations,
#    1855     space_width,
#    1856     PG.CONTENTS,
#    1857     visitor_operand_before,
#    1858     visitor_operand_after,
#    1859     visitor_text,
#    1860 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/PyPDF2/_page.py:1356, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1352     content = (
#    1353         obj[content_key].get_object() if isinstance(content_key, str) else obj
#    1354     )
#    1355     if not isinstance(content, ContentStream):
# -> 1356         content = ContentStream(content, pdf, "bytes")
#    1357 except KeyError:  # it means no content can be extracted(certainly empty page)
#    1358     return ""
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/PyPDF2/generic/_data_structures.py:877, in ContentStream.__init__(self, stream, pdf, forced_encoding)
#     875     stream_bytes = BytesIO(stream_data_bytes)
#     876 self.forced_encoding = forced_encoding
# --> 877 self.__parse_content_stream(stream_bytes)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/PyPDF2/generic/_data_structures.py:922, in ContentStream.__parse_content_stream(self, stream)
#     920 if peek == b"" or peek == 0:
#     921     break
# --> 922 stream.seek(-1, 1)
#     923 if peek.isalpha() or peek in (b"'", b'"'):
#     924     operator = read_until_regex(stream, NameObject.delimiter_pattern, True)
#
# KeyboardInterrupt:

# %%
# 3. Identify PDFs without corresponding JSON files

# Directory paths
pdf_dir = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/pdfs_new"
json_dir = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/parsed_files"

# Collect PDF file names (without extension)
pdf_ids = {
    os.path.splitext(f)[0]
    for root, _, files in os.walk(pdf_dir)
    for f in files if f.lower().endswith('.pdf')
}

# Collect JSON file names (without extension)
json_ids = {
    os.path.splitext(f)[0]
    for f in os.listdir(json_dir)
    if f.lower().endswith('.json')
}

# Identify PDFs without corresponding JSON files
failed_ids = sorted(pdf_ids - json_ids)

# Output results
print(f"❌ {len(failed_ids)} PDF files failed to convert to JSON:\n")
for fid in failed_ids:
    print(f"- {fid}.pdf")
# Out:
# ❌ 0 PDF files failed to convert to JSON:

# %% [markdown]
# ### Step 4: Analyze Feedback and Assign Labels to Original Data
#
# Process feedback documents and enrich the original dataset by assigning meaningful review labels based on combined JSON and Excel data analysis.

# %% [markdown]
# #### 4.1: Explore the raw feedback json.txt File
#
# Objective: To get an initial understanding of the raw JSON dataset structure and overall content before further processing.
#
# This step includes:
# 1) Verifying if the dataset contains more than 2,000 entries. During initial processing, some issues were encountered because the dataset contained only about 100 documents, which was insufficient for reliable analysis. Therefore, it is necessary to verify that the dataset contains more than 2,000 entries to ensure adequate data volume for meaningful processing and results.
# 2) Extracting all unique field (column) names across the entries.
# 3) Printing one sample entry (LinkTitle == D-2021-1001) for manual inspection of value formatting.
# 4) Computing the frequency distribution of the Status field to understand document status coverage.

# %%
# === Step 1: Load the JSON file ===
with open("json.txt", "r", encoding="utf-8") as f:
    data = json.load(f)

# Extract all entries under "feed" -> "entry"
entries = data.get("feed", {}).get("entry", [])
print(f"✅ Total entries found: {len(entries)}\n")

# === Step 2: Extract all unique field names and flatten entries ===
all_fields = set()
all_entries_data = []

for entry in entries:
    props = entry.get("content", {}).get("properties", {})
    flat_entry = {}

    for k, v in props.items():
        # Normalize value depending on its type and presence of '__text' key
        if isinstance(v, dict):
            if v.get('_m:null') == 'true':
                flat_entry[k] = None
            else:
                flat_entry[k] = v.get('__text', "")
        else:
            flat_entry[k] = v

        all_fields.add(k)

    all_entries_data.append(flat_entry)

# Print all unique field names
print(f"🧾 Unique field names found ({len(all_fields)} fields):")
for field in sorted(all_fields):
    print(f"- {field}")
print()

# === Step 3: Print the first sample entry with a known LinkTitle ===
target_title = "D-2021-1001"
sample = next((e for e in all_entries_data if e.get("LinkTitle") == target_title), None)

if sample:
    print(f"📌 Sample entry for LinkTitle = {target_title}:\n")
    for k, v in sample.items():
        print(f"{k}: {v}")
else:
    print(f"⚠️ Entry with LinkTitle = {target_title} not found.")

print()
# Out:
# ✅ Total entries found: 2781
#
# 🧾 Unique field names found (8 fields):
# - Code
# - FundingCallID
# - InitialFeedbackHistory
# - LinkTitle
# - ProjectTitle
# - Project_x0020_Ref_x002e_
# - Status
# - __prefix
#
# 📌 Sample entry for LinkTitle = D-2021-1001:
#
# LinkTitle: D-2021-1001
# Project_x0020_Ref_x002e_: S003422N
# Code: 3M210599
# Status: Initial
# FundingCallID: 39524
# ProjectTitle: Multiomic Integration of cell-free DNA profiles to Advance Disease Outcome
# InitialFeedbackHistory: 08/09/2023
# You now submitted the data management questions from your grant application, at this stage of your project FWO expects a more detailed DMP using the Flemish standard DMP template. You can find the template in DMPonline.be and on the FWO website together with more information about the FWO DMP requirements: https://www.fwo.be/en/the-fwo/research-policy/data-management-plan/. Consult our website for more guidance on how to write a DMP: www.kuleuven.be/rdm/en/guidance
#
# 08/09/2023
# You now submitted the data management questions from your application, at this stage of your project FWO expects a more detailed DMP using the Flemish standard DMP template. You can find the template in DMPonline.be and on the FWO website together with more information about the FWO DMP requirements: https://www.fwo.be/en/the-fwo/research-policy/data-management-plan/. Consult our website for more guidance on how to write a DMP: www.kuleuven.be/rdm/en/guidance
#
# 08/09/2023
# You now submitted the data management questions from your application, at this stage of your project FWO expects a more detailed DMP using the Flemish standard DMP template. You can find the template in DMPonline.be and on the FWO website together with more information about the FWO data management plan requirements: https://www.fwo.be/en/the-fwo/research-policy/data-management-plan/. Consult our website for more guidance on how to write a DMP: www.kuleuven.be/rdm/en/guidance
# __prefix: m

# %%
# === Step 4: Count the distribution of the "Status" field ===
status_counter = Counter()

for entry in entries:
    val = entry.get("content", {}).get("properties", {}).get("Status", "")
    
    # Extract and clean status value
    if isinstance(val, dict):
        status = val.get("__text", "").strip()
    elif isinstance(val, str):
        status = val.strip()
    else:
        status = ""

    # Remove leading numbers and dots (e.g., "5. Reviewed" -> "Reviewed")
    cleaned_status = re.sub(r"^\d+\.\s*", "", status) if status else "<Empty>"
    status_counter[cleaned_status] += 1

# Print status distribution
print("📊 Status field distribution:\n")
for status, count in status_counter.most_common():
    print(f"{status}: {count} times")
# Out:
# 📊 Status field distribution:
#
# Initial: 2333 times
# Intermediate: 228 times
# No DMP: 200 times
# Final: 20 times

# %% [markdown]
# #### 4.2: Merge Excel Columns into JSON & Inspect InitialDMPReviewStatus
#
# **Reason for merging Excel data:**
#
# The initial feedback JSON from SharePoint contained limited fields like LinkTitle, Project_x0020_Ref_x002e_, Code, Status, FundingCallID, and InitialFeedbackHistory, but lacked crucial fields such as Funder and InitialDMPReviewStatus.
#
# While processing a smaller set of about 100 feedback JSON files, I found InitialDMPReviewStatus essential for accurate labeling. The larger dataset with 2,000+ files only had basic Status values (Initial, Intermediate, No DMP, Final) which appeared frequently but were insufficient for precise classification.
#
# However, the Excel file Copy of AllProjectFolders.xlsx from the DMP Monitoring Platform includes the missing Funder and InitialDMPReviewStatus fields. Merging these into the JSON dataset ensures richer data for consistent processing and better labeling.
#
# **This step includes:**
#
# 1. Enrich the original json.txt data with two additional fields: Funder and InitialDMPReviewStatus, sourced from the Excel file.
# 2. Merge Funder and InitialDMPReviewStatus into each JSON entry based on LinkTitle.
# 2. Save the updated structure as items_2400.json.
# 3. Analyze distribution of InitialDMPReviewStatus, and count how many entries are missing or empty.

# %%
# === 1. Load the Excel and build a mapping: LinkTitle -> {Funder, InitialDMPReviewStatus} ===
excel_df = pd.read_excel("Copy of AllProjectFolders.xlsx")

# Normalize column names (remove whitespace)
excel_df.columns = [col.strip().replace(" ", "") for col in excel_df.columns]

# Build dictionary for quick lookup by LinkTitle
excel_map = {
    str(row["LinkTitle"]).strip(): {
        "Funder": str(row.get("Funder", "")).strip(),
        "InitialDMPReviewStatus": str(row.get("InitialDMPReviewStatus", "")).strip()
    }
    for _, row in excel_df.iterrows()
    if pd.notna(row.get("LinkTitle"))
}

# === 2. Load the original JSON file ===
with open("json.txt", "r", encoding="utf-8") as f:
    data = json.load(f)

entries = data.get("feed", {}).get("entry", [])

# === 3. Merge Excel data into JSON entries ===
for entry in entries:
    props = entry.get("content", {}).get("properties", {})

    # Extract LinkTitle from the entry
    linktitle_val = props.get("LinkTitle", {})
    linktitle = linktitle_val.get("__text", "").strip() if isinstance(linktitle_val, dict) else str(linktitle_val).strip()

    # Inject Excel data if available
    if linktitle in excel_map:
        props["Funder"] = excel_map[linktitle]["Funder"]
        props["InitialDMPReviewStatus"] = excel_map[linktitle]["InitialDMPReviewStatus"]

# === 4. Save merged results to a new JSON file ===
with open("items_2400.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print("✅ Merged Excel data into JSON and saved to 'items_2400.json'\n")
# Out:
# ✅ Merged Excel data into JSON and saved to 'items_2400.json'

# %%
# 📊 Check InitialDMPReviewStatus Distribution

import math

def is_empty(val):
    """Determine if a value is considered empty (None, '', 'nan', or NaN)."""
    if val is None:
        return True
    if isinstance(val, float) and math.isnan(val):
        return True
    if isinstance(val, str):
        return val.strip().lower() in ("", "nan")
    return False

# === 1. Load the updated JSON file ===
with open("items_2400.json", "r", encoding="utf-8") as f:
    data = json.load(f)

entries = data.get("feed", {}).get("entry", [])

# === 2. Analyze InitialDMPReviewStatus field ===
status_counter = Counter()
empty_count = 0
empty_titles = []

for entry in entries:
    props = entry.get("content", {}).get("properties", {})
    raw_val = props.get("InitialDMPReviewStatus", "")

    # Extract value depending on data type
    status = raw_val.get("__text", "").strip() if isinstance(raw_val, dict) else str(raw_val).strip()

    if is_empty(status):
        empty_count += 1
        # Track LinkTitle or fallback ID for review
        linktitle_val = props.get("LinkTitle", "")
        linktitle = linktitle_val.get("__text", "").strip() if isinstance(linktitle_val, dict) else str(linktitle_val).strip()
        empty_titles.append(linktitle or entry.get("id", ""))
    else:
        status_counter[status] += 1

# === 3. Output summary ===
print(f"❗ Entries with empty InitialDMPReviewStatus: {empty_count}\n")

print("📊 InitialDMPReviewStatus value distribution:")
for status, count in status_counter.most_common():
    print(f"- {status}: {count}")
# Out:
# ❗ Entries with empty InitialDMPReviewStatus: 602
#
# 📊 InitialDMPReviewStatus value distribution:
# - Reviewed: 2147
# - Reviewed, new upload needed: 25
# - Review Started: 3
# - Review required by reviewer: 3
# - Reviewed by reviewer: 1

# %% [markdown]
# #### 4.3: Filter and Generate Review JSON Files
#
# **Objective:** Generate individual review JSON files for entries with specific review statuses. Each file includes selected fields and a computed label.
#
# **Steps:**
#
# 1. Define Target Statuses
# Only process entries whose InitialDMPReviewStatus is one of the following: Review required by reviewer;Reviewed;Reviewed by reviewer;Reviewed, new upload needed;Entries with other statuses will be skipped. Entries with other statuses—such as empty, Review Started, or similar—are skipped because they either indicate that the review has not started or is incomplete. These entries do not provide enough information to reliably apply the labeling criteria.
#
# 2. From each matching entry, extract the fields 'LinkTitle', 'Status', 'InitialDMPReviewStatus', 'Funder', 'ProjectTitle', and 'InitialFeedbackHistory'. The InitialFeedbackHistory field was additionally processed to redact any potential personal names (either full names or standalone first names) using a name-pattern heuristic and a common-word exclusion list to avoid false positives. Then, **compute the 'label' field as follows: 1) if 'InitialDMPReviewStatus' is 'Reviewed, new upload needed', set label to 'not good'; 2) if no feedback exists, set it to 'good'; 3) if feedback contains revision keywords, set it to 'intermediate DMP needed'; 4) otherwise, set it to 'good with suggestions'."**
#
# 2. Save to File
# "Write each review as a separate .json file under 'processed_data/reviews/', where each file contains 'LinkTitle', 'Status', 'InitialDMPReviewStatus', 'Funder', 'ProjectTitle', 'InitialFeedbackHistory', and 'label', with the filename derived from the 'LinkTitle'."

# %%
def is_empty(value):
    """
    Check if a value is considered empty:
    - None
    - NaN (Not a Number)
    - Empty string or 'nan' (case-insensitive)
    """
    if value is None:
        return True
    if isinstance(value, float) and math.isnan(value):
        return True
    if isinstance(value, str) and value.strip().lower() in ("", "nan"):
        return True
    return False

# Step 1: Load JSON data
with open("items_2400.json", "r", encoding="utf-8") as file:
    data = json.load(file)

entries = data.get("feed", {}).get("entry", [])

empty_count = 0                # Count how many entries have empty InitialDMPReviewStatus
status_list = []              # Collect all non-empty statuses for counting
empty_link_titles = []        # Store LinkTitle or ID for entries with empty status

for entry in entries:
    props = entry.get("content", {}).get("properties", {})

    # Extract InitialDMPReviewStatus value, handling different possible formats
    status_val = props.get("InitialDMPReviewStatus", "")
    if isinstance(status_val, dict):
        status = status_val.get("__text", "").strip()
    elif isinstance(status_val, str):
        status = status_val.strip()
    else:
        status = status_val

    # Check if the status is empty
    if is_empty(status):
        empty_count += 1

        # Extract LinkTitle or fallback to entry ID for reference
        link_title_val = props.get("LinkTitle", "")
        if isinstance(link_title_val, dict):
            link_title = link_title_val.get("__text", "").strip()
        elif isinstance(link_title_val, str):
            link_title = link_title_val.strip()
        else:
            link_title = entry.get("id", "")
        empty_link_titles.append(link_title)
    else:
        status_list.append(status)

# Count frequency of each non-empty InitialDMPReviewStatus
status_counter = Counter(status_list)

# Print summary of empty statuses
print(f"Number of entries with empty InitialDMPReviewStatus: {empty_count}\n")

# Print distribution of valid statuses
print("InitialDMPReviewStatus distribution:")
for status, count in status_counter.most_common():
    print(f"- {status}: {count}")

# Print LinkTitles or IDs of entries with empty status for inspection
print("\nEntries with empty InitialDMPReviewStatus (LinkTitle / ID):")
for lt in empty_link_titles:
    print(lt)
# Out:
# Number of entries with empty InitialDMPReviewStatus: 602
#
# InitialDMPReviewStatus distribution:
# - Reviewed: 2147
# - Reviewed, new upload needed: 25
# - Review Started: 3
# - Review required by reviewer: 3
# - Reviewed by reviewer: 1
#
# Entries with empty InitialDMPReviewStatus (LinkTitle / ID):
# D-2021-1049
# D-2021-1324
# D-2021-1327
# D-2022-1386
# D-2022-1507
# D-2022-1600
# D-2022-1635
# D-2022-1636
# D-2022-1647
# D-2022-1678
# D-2022-1726
# D-2022-1728
# D-2023-1767
# D-2023-1829
# D-2023-1932
# D-2023-2091
# D-2023-2125
# D-2023-2126
# D-2023-2131
# D-2023-2164
# D-2023-2207
# D-2023-2211
# D-2023-2221
# D-2023-2227
# D-2023-2275
# D-2023-2286
# D-2023-2314
# D-2023-2347
# D-2023-2391
# D-2023-2394
# D-2023-2395
# D-2023-2413
# D-2023-2442
# D-2023-2444
# D-2023-2452
# D-2023-2456
# D-2024-2478
# D-2024-2611
# D-2024-2622
# D-2024-2854
# D-2024-2861
# D-2024-2959
# D-2024-3027
# D-2024-3038
# D-2024-3039
# D-2024-3041
# D-2024-3042
# D-2024-3043
# D-2024-3045
# D-2024-3047
# D-2024-3048
# D-2024-3049
# D-2024-3051
# D-2024-3052
# D-2024-3053
# D-2024-3055
# D-2024-3056
# D-2024-3057
# D-2024-3059
# D-2024-3060
# D-2024-3061
# D-2024-3062
# D-2024-3063
# D-2024-3064
# D-2024-3065
# D-2024-3066
# D-2024-3070
# D-2024-3073
# D-2024-3075
# D-2024-3076
# D-2024-3077
# D-2024-3078
# D-2024-3080
# D-2024-3081
# D-2024-3082
# D-2024-3083
# D-2024-3084
# D-2024-3085
# D-2024-3087
# D-2024-3088
# D-2024-3089
# D-2024-3090
# D-2024-3094
# D-2024-3096
# D-2024-3097
# D-2024-3098
# D-2024-3099
# D-2024-3101
# D-2024-3102
# D-2024-3103
# D-2024-3104
# D-2024-3105
# D-2024-3106
# D-2024-3107
# D-2024-3108
# D-2024-3109
# D-2024-3110
# D-2024-3111
# D-2024-3113
# D-2024-3116
# D-2024-3121
# D-2024-3139
# D-2024-3148
# D-2024-3150
# D-2024-3151
# D-2024-3152
# D-2024-3153
# D-2024-3157
# D-2024-3158
# D-2024-3160
# D-2024-3173
# D-2024-3174
# D-2024-3183
# D-2024-3188
# D-2024-3189
# D-2024-3190
# D-2024-3191
# D-2024-3192
# D-2024-3195
# D-2024-3219
# D-2024-3220
# D-2024-3221
# D-2024-3222
# D-2024-3223
# D-2024-3226
# D-2024-3227
# D-2024-3228
# D-2024-3234
# D-2024-3236
# D-2024-3237
# D-2024-3238
# D-2024-3239
# D-2024-3240
# D-2024-3244
# D-2024-3245
# D-2024-3246
# D-2024-3247
# D-2024-3248
# D-2024-3250
# D-2024-3251
# D-2024-3252
# D-2024-3253
# D-2024-3254
# D-2024-3255
# D-2024-3256
# D-2024-3258
# D-2024-3259
# D-2024-3260
# D-2024-3261
# D-2024-3262
# D-2024-3263
# D-2024-3264
# D-2024-3266
# D-2024-3267
# D-2024-3268
# D-2024-3269
# D-2024-3270
# D-2024-3272
# D-2024-3273
# D-2024-3275
# D-2024-3276
# D-2024-3277
# D-2024-3278
# D-2024-3279
# D-2024-3280
# D-2024-3281
# D-2024-3283
# D-2024-3284
# D-2024-3285
# D-2024-3286
# D-2024-3287
# D-2024-3288
# D-2024-3290
# D-2024-3291
# D-2024-3292
# D-2024-3293
# D-2024-3294
# D-2024-3295
# D-2024-3296
# D-2024-3297
# D-2024-3298
# D-2024-3299
# D-2024-3300
# D-2024-3301
# D-2024-3302
# D-2024-3303
# D-2024-3304
# D-2024-3306
# D-2024-3308
# D-2024-3311
# D-2024-3312
# D-2024-3314
# D-2024-3315
# D-2024-3316
# D-2024-3317
# D-2024-3321
# D-2024-3322
# D-2024-3323
# D-2024-3324
# D-2024-3325
# D-2024-3327
# D-2024-3328
# D-2024-3329
# D-2024-3330
# D-2024-3331
# D-2024-3334
# D-2024-3335
# D-2024-3336
# D-2024-3337
# D-2024-3338
# D-2024-3339
# D-2024-3341
# D-2024-3343
# D-2024-3344
# D-2024-3345
# D-2024-3346
# D-2024-3347
# D-2024-3349
# D-2024-3350
# D-2024-3351
# D-2024-3352
# D-2024-3353
# D-2024-3357
# D-2024-3358
# D-2024-3359
# D-2024-3360
# D-2024-3361
# D-2024-3362
# D-2024-3366
# D-2024-3367
# D-2024-3368
# D-2024-3369
# D-2024-3370
# D-2024-3371
# D-2024-3372
# D-2024-3373
# D-2024-3374
# D-2024-3375
# D-2024-3376
# D-2024-3378
# D-2024-3379
# D-2024-3381
# D-2024-3382
# D-2024-3383
# D-2024-3384
# D-2024-3385
# D-2024-3386
# D-2024-3387
# D-2024-3388
# D-2024-3389
# D-2024-3391
# D-2024-3393
# D-2024-3395
# D-2024-3396
# D-2024-3397
# D-2024-3398
# D-2024-3399
# D-2024-3400
# D-2024-3402
# D-2024-3403
# D-2024-3404
# D-2024-3405
# D-2024-3406
# D-2024-3407
# D-2024-3408
# D-2024-3409
# D-2024-3411
# D-2024-3412
# D-2024-3413
# D-2024-3414
# D-2024-3415
# D-2024-3416
# D-2024-3417
# D-2024-3419
# D-2024-3420
# D-2024-3421
# D-2024-3422
# D-2024-3423
# D-2024-3424
# D-2024-3425
# D-2024-3426
# D-2024-3427
# D-2024-3428
# D-2024-3429
# D-2024-3430
# D-2024-3432
# D-2024-3433
# D-2024-3434
# D-2024-3435
# D-2024-3436
# D-2024-3437
# D-2024-3438
# D-2024-3439
# D-2024-3441
# D-2024-3442
# D-2024-3447
# D-2024-3448
# D-2024-3451
# D-2024-3453
# D-2024-3454
# D-2024-3456
# D-2024-3457
# D-2024-3458
# D-2024-3459
# D-2024-3461
# D-2024-3462
# D-2024-3464
# D-2024-3466
# D-2024-3468
# D-2024-3469
# D-2024-3470
# D-2024-3471
# D-2024-3473
# D-2024-3474
# D-2024-3475
# D-2024-3477
# D-2024-3478
# D-2024-3479
# D-2024-3481
# D-2024-3482
# D-2024-3483
# D-2024-3485
# D-2024-3486
# D-2024-3487
# D-2024-3488
# D-2024-3489
# D-2024-3490
# D-2024-3491
# D-2024-3492
# D-2024-3493
# D-2024-3494
# D-2024-3495
# D-2024-3496
# D-2024-3499
# D-2024-3500
# D-2024-3501
# D-2024-3502
# D-2024-3503
# D-2024-3504
# D-2024-3506
# D-2024-3507
# D-2024-3508
# D-2024-3510
# D-2024-3511
# D-2024-3512
# D-2024-3513
# D-2024-3514
# D-2024-3515
# D-2024-3516
# D-2024-3519
# D-2024-3520
# D-2024-3521
# D-2024-3523
# D-2024-3524
# D-2024-3525
# D-2024-3526
# D-2024-3527
# D-2024-3530
# D-2024-3531
# D-2024-3533
# D-2024-3535
# D-2024-3536
# D-2024-3538
# D-2024-3539
# D-2024-3540
# D-2024-3541
# D-2024-3542
# D-2024-3543
# D-2024-3544
# D-2024-3545
# D-2024-3546
# D-2024-3547
# D-2024-3548
# D-2024-3549
# D-2024-3550
# D-2024-3552
# D-2024-3553
# D-2024-3554
# D-2024-3555
# D-2024-3556
# D-2024-3557
# D-2024-3558
# D-2024-3559
# D-2024-3562
# D-2024-3563
# D-2024-3564
# D-2024-3565
# D-2024-3566
# D-2024-3568
# D-2024-3572
# D-2024-3575
# D-2024-3580
# D-2024-3586
# D-2024-3587
# D-2025-3588
# D-2025-3593
# D-2025-3594
# D-2025-3597
# D-2025-3598
# D-2025-3600
# D-2025-3601
# D-2025-3602
# D-2025-3604
# D-2025-3605
# D-2025-3606
# D-2025-3607
# D-2025-3608
# D-2025-3609
# D-2025-3610
# D-2025-3611
# D-2025-3612
# D-2025-3613
# D-2025-3614
# D-2025-3615
# D-2025-3617
# D-2025-3618
# D-2025-3619
# D-2025-3620
# D-2025-3622
# D-2025-3623
# D-2025-3625
# D-2025-3626
# D-2025-3627
# D-2025-3628
# D-2025-3629
# D-2025-3630
# D-2025-3631
# D-2025-3633
# D-2025-3634
# D-2025-3635
# D-2025-3637
# D-2025-3638
# D-2025-3639
# D-2025-3640
# D-2025-3641
# D-2025-3642
# D-2025-3643
# D-2025-3644
# D-2025-3645
# D-2025-3646
# D-2025-3648
# D-2025-3649
# D-2025-3650
# D-2025-3651
# D-2025-3652
# D-2025-3653
# D-2025-3654
# D-2025-3655
# D-2025-3656
# D-2025-3657
# D-2025-3658
# D-2025-3659
# D-2025-3660
# D-2025-3661
# D-2025-3662
# D-2025-3663
# D-2025-3664
# D-2025-3665
# D-2025-3666
# D-2025-3667
# D-2025-3668
# D-2025-3669
# D-2025-3670
# D-2025-3671
# D-2025-3672
# D-2025-3675
# D-2025-3676
# D-2025-3677
# D-2025-3678
# D-2025-3679
# D-2025-3680
# D-2025-3681
# D-2025-3682
# D-2025-3683
# D-2025-3684
# D-2025-3685
# D-2025-3686
# D-2025-3687
# D-2025-3688
# D-2025-3689
# D-2025-3690
# D-2025-3691
# D-2025-3692
# D-2025-3693
# D-2025-3699
# D-2025-3701
# D-2025-3702
# D-2025-3703
# D-2025-3704
# D-2025-3705
# D-2025-3706
# D-2025-3707
# D-2025-3708
# D-2025-3709
# D-2025-3710
# D-2025-3711
# D-2025-3712
# D-2025-3713
# D-2025-3714
# D-2025-3717
# D-2025-3718
# D-2025-3719
# D-2025-3723
# D-2025-3724
# D-2025-3725
# D-2025-3726
# D-2025-3727
# D-2025-3728
# D-2025-3729
# D-2025-3730
# D-2025-3731
# D-2025-3732
# D-2025-3733
# D-2025-3734
# D-2025-3736
# D-2025-3738
# D-2025-3741
# D-2025-3743
# D-2025-3745
# D-2025-3748
# D-2025-3749
# D-2025-3750
# D-2025-3751
# D-2025-3752
# D-2025-3753
# D-2025-3754
# D-2025-3755
# D-2025-3756
# D-2025-3757
# D-2025-3758
# D-2025-3759
# D-2025-3760
# D-2025-3761
# D-2025-3762
# D-2025-3763
# D-2025-3764
# D-2025-3765
# D-2025-3766
# D-2025-3767
# D-2025-3769
# D-2025-3770
# D-2025-3771
# D-2025-3772
# D-2025-3773
# D-2025-3774
# D-2025-3775
# D-2025-3776
# D-2025-3777
# D-2025-3778
# D-2025-3779
# D-2025-3780
# D-2025-3781
# D-2025-3782
# D-2025-3783
# D-2025-3784
# D-2025-3785
# D-2025-3786
# D-2025-3787
# D-2025-3788
# D-2025-3789
# D-2025-3790
# D-2025-3791
# D-2025-3792
# D-2025-3793
# D-2025-3794
# D-2025-3795
# D-2025-3796
# D-2025-3797
# D-2025-3798
# D-2025-3799
# D-2025-3800
# D-2025-3801
# D-2025-3802
# D-2025-3803
# D-2025-3804
# D-2025-3805
# D-2025-3806
# D-2025-3807
# D-2025-3808
# D-2025-3809
# D-2025-3810
# D-2025-3811
# D-2025-3812
# D-2025-3813
# D-2025-3814
# D-2025-3815
# D-2025-3816
# D-2025-3817
# D-2025-3818
# D-2025-3819
# D-2025-3820
# D-2025-3821
# D-2025-3822
# D-2025-3823
# D-2025-3824
# D-2025-3825
# D-2025-3826
# D-2025-3827
# D-2025-3828
# D-2025-3829
# D-2025-3830
# D-2025-3831

# %%
# === CONFIGURATION ===
base_dir = "/Users/JADEPOTTER5/Downloads/DMP-MT"
input_path = os.path.join(base_dir, "items_2400.json")
output_dir = os.path.join(base_dir, "processed_data", "reviews")
os.makedirs(output_dir, exist_ok=True)

valid_statuses = {
    "Review required by reviewer",
    "Reviewed",
    "Reviewed by reviewer",
    "Reviewed, new upload needed"
}

suggestion_keywords = [
    "ask for a revision",
    "upload intermediate",
    "please submit an intermediate dmp",
    "can you resubmit a new version",
    "submit as intermediate",
    "please update your dmp"
]
pattern = re.compile("|".join(suggestion_keywords), re.IGNORECASE)

# === Utility functions ===

def get_text(val):
    """Extract __text from dict or strip strings."""
    if isinstance(val, dict):
        return val.get("__text", "").strip()
    elif isinstance(val, str):
        return val.strip()
    return ""

def clean_status(text):
    """Remove leading numbering from status, e.g. '1. Submitted' -> 'Submitted'"""
    return re.sub(r"^\d+\.\s*", "", text).strip()

def remove_names(text):
    """Redact likely names from text using simple heuristics."""
    if not text:
        return ""

    # Regex for detecting capitalized names (including hyphenated)
    name_pattern = re.compile(r"\b([A-Z][a-z]+(?:[-\s][A-Z][a-z]+)?)\b", re.UNICODE)

    # List of common non-name words to exclude from redaction
    common_words = {"Please", "Thank", "Note", "Submit", "Update", "Upload", "Review", "Provide"}

    def should_redact(word):
        return word not in common_words

    # Replace words matching the pattern but not in common list
    redacted = []
    for token in text.split():
        # Remove punctuation for comparison
        word_clean = re.sub(r"[^\w\-]", "", token)
        if name_pattern.fullmatch(word_clean) and should_redact(word_clean):
            redacted.append("[REDACTED]")
        else:
            redacted.append(token)

    return " ".join(redacted)

# %%
# === Load JSON entries ===
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)
entries = data.get("feed", {}).get("entry", [])

# === Generate filtered review JSON files ===
count_skipped = 0
count_saved = 0

for entry in entries:
    props = entry.get("content", {}).get("properties", {})

    linktitle = get_text(props.get("LinkTitle"))
    status = get_text(props.get("Status"))
    initial_dmp_review_status = clean_status(get_text(props.get("InitialDMPReviewStatus")))
    funder = get_text(props.get("Funder"))
    project_title = get_text(props.get("ProjectTitle"))

    # Raw feedback text
    raw_feedback = get_text(props.get("InitialFeedbackHistory"))
    feedback = remove_names(raw_feedback)

    if initial_dmp_review_status not in valid_statuses:
        count_skipped += 1
        continue

    # Label assignment logic
    if initial_dmp_review_status == "Reviewed, new upload needed":
        label = "not good"
    elif not raw_feedback:
        label = "good"
    elif pattern.search(raw_feedback):
        label = "intermediate DMP needed"
    else:
        label = "good with suggestions"

    review_data = {
        "LinkTitle": linktitle,
        "Status": status,
        "InitialDMPReviewStatus": initial_dmp_review_status,
        "Funder": funder,
        "ProjectTitle": project_title,
        "InitialFeedbackHistory": feedback,
        "label": label
    }

    safe_filename = linktitle.replace("/", "_").replace("\\", "_") + ".json"
    review_path = os.path.join(output_dir, safe_filename)
    with open(review_path, "w", encoding="utf-8") as f:
        json.dump(review_data, f, ensure_ascii=False, indent=2)

    count_saved += 1

print(f"\n✅ Finished generating review JSON files.")
print(f"🚫 Entries skipped due to invalid status: {count_skipped}")
print(f"📄 Review files generated: {count_saved}")
# Out:
# ✅ Finished generating review JSON files.
# 🚫 Entries skipped due to invalid status: 605
# 📄 Review files generated: 2176

# %% [markdown]
# #### 4.4: Analysis of Status Discrepancies between Original JSON and Excel and generate the rest Review Json file
#
# **Reason**
#
# To maximize the amount of labeled DMP review data, I compare the original JSON dataset with the Excel file (Copy of AllProjectFolders.xlsx).
# The JSON dataset contains more entries than the Excel sheet, so I aim to identify and label those additional records where possible.
#
# **Steps**
#
# 1. **Compare** `InitialDMPReviewStatus` between original JSON and Excel:
#    - Count empty values.
#    - Show status distribution.
#
# 2. Compare LinkTitles between JSON and CSV by **Identify** `LinkTitle`. Identify records that exist only in the JSON or CSV file (i.e., JSON-only entries).
#
# 3. For these **JSON-only entries**:
#    - Analyze `InitialFeedbackHistory`:
#      - Count how many are empty vs. non-empty.
#      - Show `Status` distribution by feedback presence.
#    - Automatically **assign a label** based on feedback content and status:
#      - `good`: No feedback.
#      - `good with suggestions`: Some feedback but not critical.
#      - `intermediate DMP needed`: Feedback contains revision/submit keywords.
#
# 4. **Output** labeled review files in JSON format, one per entry.
#
#   - Directory: `processed_data/reviews/`
#   - Each file includes:
#     - `LinkTitle`, `Status`, `InitialDMPReviewStatus`, `Funder`, `ProjectTitle`, `InitialFeedbackHistory`, and assigned `label`.

# %%
# === Helper: Safe text extractor ===
def extract_text(field):
    if field is None:
        return ""
    if isinstance(field, dict):
        if field.get("_m:null") == "true":
            return ""
        return field.get("__text", "").strip()
    if isinstance(field, str):
        return field.strip()
    return str(field).strip()

# === Step 1: Load Excel and summarize InitialDMPReviewStatus ===
df = pd.read_excel("Copy of AllProjectFolders.xlsx")
df['LinkTitle_clean'] = df['LinkTitle'].astype(str).str.strip()
df['InitialDMPReviewStatus_clean'] = df['InitialDMPReviewStatus'].astype(str).str.strip()

empty_count_csv = df['InitialDMPReviewStatus_clean'].str.lower().isin(['', 'nan']).sum()
print(f"CSV InitialDMPReviewStatus empty count: {empty_count_csv}")

print("\nTarget status distribution in CSV:")
target_statuses = [
    "Review required by reviewer",
    "Reviewed",
    "Reviewed by reviewer",
    "Reviewed, new upload needed"
]
for status in target_statuses:
    count = df['InitialDMPReviewStatus_clean'].value_counts().get(status, 0)
    print(f"- {status}: {count}")

# === Step 2: Load JSON and summarize InitialDMPReviewStatus ===
with open("items_2400.json", encoding="utf-8") as f:
    entries = json.load(f).get("feed", {}).get("entry", [])

linktitle_to_props = {}
json_data = {}

for entry in entries:
    props = entry.get("content", {}).get("properties", {})
    lt = extract_text(props.get("LinkTitle"))
    status = extract_text(props.get("InitialDMPReviewStatus"))
    if lt:
        json_data[lt] = status
        linktitle_to_props[lt] = props

empty_count_json = sum(1 for s in json_data.values() if s.lower() in ["", "nan"])
print(f"\nJSON InitialDMPReviewStatus empty count: {empty_count_json}")

print("\nInitialDMPReviewStatus distribution in JSON:")
for status, count in Counter(s for s in json_data.values() if s.lower() not in ["", "nan"]).most_common():
    print(f"- {status}: {count}")
# Out:
# CSV InitialDMPReviewStatus empty count: 549
#
# Target status distribution in CSV:
# - Review required by reviewer: 3
# - Reviewed: 2148
# - Reviewed by reviewer: 1
# - Reviewed, new upload needed: 25
#
# JSON InitialDMPReviewStatus empty count: 602
#
# InitialDMPReviewStatus distribution in JSON:
# - Reviewed: 2147
# - Reviewed, new upload needed: 25
# - Review Started: 3
# - Review required by reviewer: 3
# - Reviewed by reviewer: 1

# %%
# === Step 3: Compare LinkTitles between JSON and CSV ===

# Load CSV data
df = pd.read_excel("Copy of AllProjectFolders.xlsx")

# Clean LinkTitle and Status columns
df['LinkTitle_clean'] = df['LinkTitle'].astype(str).str.strip()
df['Status_clean'] = df['InitialDMPReviewStatus'].astype(str).str.strip()

# Create CSV data dict: {LinkTitle -> Status}
csv_data = dict(zip(df['LinkTitle_clean'], df['Status_clean']))
print(f"Total records in CSV: {len(csv_data)}")

# Compare with JSON data (assumes `json_data` is already defined as {LinkTitle -> Status})
only_in_json = set(json_data) - set(csv_data)
only_in_csv = set(csv_data) - set(json_data)
shared = set(json_data) & set(csv_data)

# Find records with different status between JSON and CSV
diff_status = [
    (lt, json_data[lt], csv_data[lt])
    for lt in shared
    if json_data[lt] != csv_data[lt]
]

# Identify missing or empty statuses
json_empty = {k for k, v in json_data.items() if not v or str(v).lower() == "nan"}
csv_empty = {k for k, v in csv_data.items() if not v or str(v).lower() == "nan"}

json_empty_only = json_empty - csv_empty
csv_empty_only = csv_empty - json_empty

# === Print Summary ===
print(f"LinkTitles only in JSON: {len(only_in_json)}")
print(f"LinkTitles only in CSV: {len(only_in_csv)}")
print(f"LinkTitles with different status values: {len(diff_status)}")
print(f"Empty in JSON but not in CSV: {len(json_empty_only)}")
print(f"Empty in CSV but not in JSON: {len(csv_empty_only)}")

# === Print Examples ===
print("\nExamples of mismatched status values (up to 10):")
for i, (lt, jst, cst) in enumerate(diff_status[:10]):
    print(f"{i+1}. {lt} | JSON: {jst} | CSV: {cst}")

print("\nExamples where JSON status is empty but CSV is not:")
for i, lt in enumerate(list(json_empty_only)[:10]):
    print(f"{i+1}. {lt} | CSV: {csv_data.get(lt)}")

print("\nExamples where CSV status is empty but JSON is not:")
for i, lt in enumerate(list(csv_empty_only)[:10]):
    print(f"{i+1}. {lt} | JSON: {json_data.get(lt)}")
# Out:
# Total records in CSV: 2728
# LinkTitles only in JSON: 57
# LinkTitles only in CSV: 4
# LinkTitles with different status values: 0
# Empty in JSON but not in CSV: 57
# Empty in CSV but not in JSON: 4
#
# Examples of mismatched status values (up to 10):
#
# Examples where JSON status is empty but CSV is not:
# 1. D-2025-3814 | CSV: None
# 2. D-2025-3790 | CSV: None
# 3. D-2025-3792 | CSV: None
# 4. D-2025-3789 | CSV: None
# 5. D-2025-3822 | CSV: None
# 6. D-2025-3802 | CSV: None
# 7. D-2024-2622 | CSV: None
# 8. D-2025-3819 | CSV: None
# 9. D-2025-3784 | CSV: None
# 10. D-2025-3827 | CSV: None
#
# Examples where CSV status is empty but JSON is not:
# 1. nan | JSON: None
# 2. D-2024-3310 | JSON: None
# 3. D-2024-3242 | JSON: None
# 4. D-2024-3356 | JSON: None

# %% [markdown]
# I skip entries where Excel has empty InitialDMPReviewStatus but JSON is not: These are very few (only 4 cases). Manual review showed that the Excel-side status is missing, and no label could be reliably assigned, so I skip them.

# %%
# === Step 4: Analyze InitialFeedbackHistory for JSON-only entries ===
empty_feedback, nonempty_feedback = [], []

for lt in only_in_json:
    props = linktitle_to_props.get(lt, {})
    feedback = extract_text(props.get("InitialFeedbackHistory"))
    status = extract_text(props.get("Status"))
    if not feedback:
        empty_feedback.append((lt, status))
    else:
        nonempty_feedback.append((lt, status, feedback))

print(f"\n🧾 Among JSON-only entries ({len(only_in_json)} total):")
print(f"- EMPTY InitialFeedbackHistory: {len(empty_feedback)}")
print(f"- NON-EMPTY InitialFeedbackHistory: {len(nonempty_feedback)}")

# === Step 5: Status distribution split by InitialFeedbackHistory ===
print("\n📊 Status distribution:")

print("\n🔸 EMPTY InitialFeedbackHistory:")
for status, count in Counter(s for _, s in empty_feedback).items():
    print(f"- {status or '[Blank]'}: {count}")

print("\n🔹 NON-EMPTY InitialFeedbackHistory:")
for status, count in Counter(s for _, s, _ in nonempty_feedback).items():
    print(f"- {status or '[Blank]'}: {count}")
# Out:
# 🧾 Among JSON-only entries (57 total):
# - EMPTY InitialFeedbackHistory: 47
# - NON-EMPTY InitialFeedbackHistory: 10
#
# 📊 Status distribution:
#
# 🔸 EMPTY InitialFeedbackHistory:
# - Initial: 11
# - No DMP: 36
#
# 🔹 NON-EMPTY InitialFeedbackHistory:
# - Initial: 9
# - Intermediate: 1

# %% [markdown]
# **🧠Labeling Rules Summary**
#
# Each entry is labeled based on a combination of Status and InitialFeedbackHistory. The goal is to focus on meaningful entries and apply consistent, interpretable classification
#
# 🏷️ Step 1: Filtering Criteria
# - Skip the entry if:
#     - Status is "No DMP" → No reviewable content.
#     - Status is not "Initial" → Only "Initial" stage is considered valuable for this labeling.
#
# 🏷️ Step 2: Label Assignment (for Status = "Initial")
#
# | **Label**                 | **Condition**                                                                                                                                            |
# | ------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | `good`                    | `InitialFeedbackHistory` is empty.                                                                                                                       |
# | `intermediate DMP needed` | Feedback contains **intermediate-related** keywords such as:<br>• `"ask for a revision"`<br>• `"submit as intermediate"`<br>• `"please update your DMP"` |
# | `not good`                | Feedback contains **negative quality signals**, e.g.:<br>• `"still waiting"`<br>• `"not receive"`<br>• `"quite some information missing"`                |
# | `good with suggestions`   | Feedback exists, but contains **none** of the intermediate-related or negative keywords above.                                                           |

# %%
# === Step 5: Auto-labeling and save review files ===

# Keywords（intermediate）
label_pattern = re.compile(
    "|".join([
        "ask for a revision",
        "upload intermediate",
        "please submit an intermediate dmp",
        "can you resubmit a new version",
        "submit as intermediate",
        "please update your dmp"
    ]),
    re.IGNORECASE
)

# Keywords（not good）
not_good_pattern = re.compile(
    "|".join([
        r"still waiting( for)?",
        r"not receive",
        r"a few things missing",
        r"quite some information missing"
    ]),
    re.IGNORECASE
)

label_counts = {
    "good": 0,
    "good with suggestions": 0,
    "intermediate DMP needed": 0,
    "skipped_no_dmp": 0
}
output_dir = os.path.join("processed_data", "reviews")
os.makedirs(output_dir, exist_ok=True)

generated_count = 0

for lt in only_in_json:
    props = linktitle_to_props.get(lt, {})
    status = extract_text(props.get("Status"))

    if status == "No DMP":
        label_counts["skipped_no_dmp"] += 1
        continue
    if status != "Initial":
        continue

    feedback = extract_text(props.get("InitialFeedbackHistory"))
    
    if not feedback:
            label = "good"
    elif not_good_pattern.search(feedback):
        label = "not good"
    elif label_pattern.search(feedback):
        label = "intermediate DMP needed"
    else:
        label = "good with suggestions"

    label_counts[label] += 1

    review = {
        "LinkTitle": lt,
        "Status": status,
        "InitialDMPReviewStatus": extract_text(props.get("InitialDMPReviewStatus")),
        "Funder": extract_text(props.get("Funder")),
        "ProjectTitle": extract_text(props.get("ProjectTitle")),
        "InitialFeedbackHistory": feedback,
        "label": label
    }

    with open(os.path.join(output_dir, f"{lt}.json"), "w", encoding="utf-8") as f:
        json.dump(review, f, ensure_ascii=False, indent=2)
    generated_count += 1

print(f"\n✅ Generated {generated_count} review JSON files.")
print(f"📁 Total in {output_dir}: {len(os.listdir(output_dir))}")
print("📊 Label distribution:")
for label, count in label_counts.items():
    print(f"- {label}: {count}")
# Out:
# ✅ Generated 20 review JSON files.
# 📁 Total in processed_data/reviews: 2199
# 📊 Label distribution:
# - good: 11
# - good with suggestions: 8
# - intermediate DMP needed: 1
# - skipped_no_dmp: 36

# %%
# === Step 6: Analyze review for 'intermediate DMP needed' ===
review_dir = os.path.join("processed_data", "reviews")

for filename in os.listdir(review_dir):
    if not filename.endswith(".json"):
        continue

    filepath = os.path.join(review_dir, filename)
    with open(filepath, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    if data.get("label") == "intermediate DMP needed":
        print(f"📄 File: {filename}")
        print("📝 InitialFeedbackHistory:")
        print(data.get("InitialFeedbackHistory", "[No feedback found]"))
        break  # Only one expected
# Out:
# 📄 File: D-2021-1237.json
# 📝 InitialFeedbackHistory:
# 24/06/2022 3. [REDACTED] Please update your DMP when you have all the ethical approvals, you can submit this DMP as intermediate. 4. [REDACTED] DICOM is also a metadata standard that you can mention here. 7. [REDACTED] [REDACTED] you considered to use repositories for data sharing and preservation? [REDACTED] there are no domain specific repositories in your field you can use KU [REDACTED] RDR (www.kuleuven.be/rdm/en/rdr) where you can keep your data under restricted access if you can't fully anonymize the data

# %% [markdown]
# **⚠️ Notes on Labeling Ambiguity (Step 6)**
#
# While auto-labeling using `Status` and keyword-based `InitialFeedbackHistory` generally works, there are limitations—especially in distinguishing between `not good` and `intermediate DMP needed`.
#
# **Observations**
# - Feedback labeled as `not good` often includes phrases like:
#   - "convert your DMP to that template now"
#   - "submit a new version of the DMP"
#   - "upload a new DMP"
#   - "you uploaded an older version of the DMP template"
#   - "please complete the most recent version of the DMP template"
# - These overlap semantically with phrases currently used to detect `intermediate DMP needed`, such as:
#   - "ask for a revision"
#   - "resubmit"
#
# **Current Application**
# - Among the extra review entries (found only in JSON), only **one** was labeled `intermediate DMP needed`.
# - This label was assigned based on the specific keyword:
#   > "submit this DMP as intermediate"
# - This conservative approach helps avoid overclassification.
#
# **Recommendation**
# - The current rule is acceptable for now.
# - If auto-labeling is extended (especially only using `Status` and `InitialFeedbackHistory`), the use of ambiguous phrases like "ask for a revision" should be more clearly defined.

# %% [markdown]
# ### Step 5: Build Dataset Records and Split into Train/Dev/Test
#
# **📂 : Generate Records File**
# - Match entries that have **both parsed files and review files** by `LinkTitle`.
# - Load external metadata file (e.g., `dmpmt.json`) and map it by `LinkTitle` for fast lookup.
# - For each valid entry, create a record containing:
#   - `LinkTitle`
#   - File paths to the parsed JSON and review JSON
#   - Corresponding metadata
# - Save all records to `processed_data/records.json`.
#
# **✂️ Split Dataset**
# - Load `records.json` and randomly split the dataset into:
#   - **Train:** 90%
#   - **Dev:** 5%
#   - **Test:** 5%
# - For each split, create separate directories:
#   - `train/parsed_files/`, `train/reviews/`
#   - `dev/parsed_files/`, `dev/reviews/`
#   - `test/parsed_files/`, `test/reviews/`
# - Copy the corresponding parsed and review JSON files into the appropriate split folders.

# %%
## ==== Create a master record of all valid files for future dataset splitting ==== 

# ✅ Set your data directory here
data_dir = Path("/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data")
parsed_dir = data_dir / "parsed_files"
reviews_dir = data_dir / "reviews"
records_path = data_dir / "records.json"
metadata_path = Path("/Users/JADEPOTTER5/Downloads/DMP-MT/dmpmt.json")

def main():
    # Load full metadata (assumed to be a list of dicts)
    with open(metadata_path, "r") as f:
        all_metadata = json.load(f)

    # Convert to a dict for fast lookup by LinkTitle
    metadata_dict = {item['LinkTitle']: item for item in all_metadata}

    # Get all parsed and reviewed file IDs (stems of JSON filenames)
    parsed_ids = {f.stem for f in parsed_dir.glob("*.json")}
    review_ids = {f.stem for f in reviews_dir.glob("*.json")}

    # Only keep files that have both parsed and review data
    valid_ids = sorted(parsed_ids & review_ids)

    if not valid_ids:
        print("⚠️ No valid files found for dataset construction.")
        return

    # Build the master records list
    records = []
    for pid in valid_ids:
        metadata = metadata_dict.get(pid, {})
        records.append({
            "id": pid,
            "parsed_file": str(parsed_dir / f"{pid}.json"),
            "review_file": str(reviews_dir / f"{pid}.json"),
            "metadata": metadata
        })

    # Save to records.json
    with open(records_path, "w") as f:
        json.dump(records, f, indent=2, ensure_ascii=False)

    print(f"✅ Successfully saved {len(records)} records to {records_path}")

if __name__ == "__main__":
    main()

# %%
# Step 7: Split the dataset into train/dev/test sets

import json
import shutil
import random
from pathlib import Path
from sklearn.model_selection import train_test_split

# Set random seed for reproducibility
random.seed(42)

# Define paths
base_dir = Path("/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data")
records_path = base_dir / "records.json"
splits_dir = base_dir / "splits"

# Load records
with open(records_path) as f:
    records = json.load(f)

# Check if records exist
if not records:
    print("⚠️ No valid records found in records.json. Please run the record generation script first.")
    exit()

# Create index list and split into train/dev/test
ids = list(range(len(records)))
train_ids, temp_ids = train_test_split(ids, test_size=0.1, random_state=42)  # 90% train
dev_ids, test_ids = train_test_split(temp_ids, test_size=0.5, random_state=42)  # 5% dev, 5% test

splits = {
    "train": train_ids,
    "dev": dev_ids,
    "test": test_ids
}

# Create directories and copy files
for split_name, split_ids in splits.items():
    split_base = splits_dir / split_name
    parsed_out = split_base / "parsed_files"
    reviews_out = split_base / "reviews"

    # Remove existing split folder if any
    if split_base.exists():
        shutil.rmtree(split_base)

    # Create directories
    parsed_out.mkdir(parents=True)
    reviews_out.mkdir(parents=True)

    # Copy corresponding parsed and review files
    for idx in split_ids:
        rec = records[idx]
        shutil.copy(rec["parsed_file"], parsed_out / Path(rec["parsed_file"]).name)
        shutil.copy(rec["review_file"], reviews_out / Path(rec["review_file"]).name)

    print(f"✅ {split_name}: {len(split_ids)} samples")

print(f"\n🎉 Dataset successfully split and saved to: {splits_dir}")

# %% [markdown]
# ### Step 6: Ready for Hugging Face dataset
#
# This step combines parsed documents and review files into a single JSON Lines file for Hugging Face.
# - Load records.json with file paths.
# - For each record, check both parsed and review files exist; skip if missing.
# - Extract clean_full_text or fallback to raw text from parsed file.
# - Collect metadata and review info: LinkTitle, ProjectTitle, Funder, Status, InitialDMPReviewStatus, InitialFeedbackHistory, and label.
# - Save all samples to hf_dataset.jsonl for efficient use with Hugging Face.
#
# Samples with missing or incomplete files are skipped and counted for reporting. All fields are preserved even if empty, ensuring consistent schema across samples.
#
# Output file example: 'processed_data/hf_dataset.jsonl'

# %%
# -*- coding: utf-8 -*-
import json
import jsonlines
import os

def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

def prepare_hf_dataset(records_path, output_path):
    print(f"📥 Loading records from: {records_path}")
    records = load_json(records_path)

    samples = []
    skipped_count = 0

    for record in records:
        paper_id = record.get("id")
        parsed_file = record.get("parsed_file")
        review_file = record.get("review_file")

        if not paper_id or not parsed_file or not review_file:
            print(f"⚠️ Skipping due to missing id or files: {record}")
            skipped_count += 1
            continue

        if not os.path.exists(parsed_file):
            print(f"❗ Parsed file missing for {paper_id}, skipping")
            skipped_count += 1
            continue
        if not os.path.exists(review_file):
            print(f"❗ Review file missing for {paper_id}, skipping")
            skipped_count += 1
            continue

        parsed_json = load_json(parsed_file)
        review_json = load_json(review_file)

        # Extract clean_full_text; if empty, use full_text
        clean_text = parsed_json.get("clean_full_text")
        if not clean_text:
            clean_text = parsed_json.get("content", {}).get("full_text", "")

        # Read fields from review json (keep even if empty)
        sample = {
            "LinkTitle": review_json.get("LinkTitle", paper_id),
            "ProjectTitle": review_json.get("ProjectTitle", ""),
            "Funder": review_json.get("Funder", ""),
            "Clean_full_text": clean_text,
            "Status": review_json.get("Status", ""),
            "InitialDMPReviewStatus": review_json.get("InitialDMPReviewStatus", ""),
            "InitialFeedbackHistory": review_json.get("InitialFeedbackHistory", ""),
            "label": review_json.get("label", "")
        }

        samples.append(sample)

    print(f"✅ Finished processing. Total valid samples: {len(samples)}; skipped: {skipped_count}")
    print(f"💾 Writing output to {output_path}")

    with jsonlines.open(output_path, "w") as writer:
        writer.write_all(samples)

    print("🎉 Dataset preparation complete!")

if __name__ == "__main__":
    records_path = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/records.json"
    output_path = "/Users/JADEPOTTER5/Downloads/DMP-MT/processed_data/hf_dataset.jsonl"
    prepare_hf_dataset(records_path, output_path)
